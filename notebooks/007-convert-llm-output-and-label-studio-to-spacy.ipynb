# %% [markdown]
# # Set up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

# %%
import sys
sys.path.insert(0, '..')

# %% [markdown]
# # Constants

# %%
VERSION = '20240706095040'

# %% [markdown]
# # Load holdout label studio data

# %%
HOLDOUT_LABEL_STUDIO_FP = '../data/output/llm_extract_output_holdout_label_studio.json'
with open(HOLDOUT_LABEL_STUDIO_FP, 'r') as f:
    holdout_raw = json.load(f)

# %%
holdout_raw[:5]
# Out:
# [{'id': 996,
#   'annotations': [{'id': 15,
#     'completed_by': 1,
#     'result': [{'value': {'start': 15,
#        'end': 51,
#        'text': 'looks out over beautiful green lawns',
#        'labels': ['VIEW']},
#       'id': '780b56b2-376f-4afb-b7ac-df001a0ae76e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 59,
#        'end': 97,
#        'text': 'Hudson River and the Statue of Liberty',
#        'labels': ['VIEW']},
#       'id': 'bc96d157-1925-4b9a-8d5b-7a420b4fede2',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-09T03:42:06.515569Z',
#     'updated_at': '2024-07-09T03:42:06.515591Z',
#     'draft_created_at': None,
#     'lead_time': 25.821,
#     'prediction': {'id': 3091,
#      'model_version': 'one',
#      'created_ago': '0\xa0minutes',
#      'result': [{'id': '780b56b2-376f-4afb-b7ac-df001a0ae76e',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 15,
#         'end': 51,
#         'score': 0.7,
#         'text': 'looks out over beautiful green lawns',
#         'labels': ['VIEW']}},
#       {'id': 'bc96d157-1925-4b9a-8d5b-7a420b4fede2',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 59,
#         'end': 97,
#         'score': 0.8,
#         'text': 'Hudson River and the Statue of Liberty',
#         'labels': ['VIEW']}}],
#      'score': 0.75,
#      'cluster': None,
#      'neighbors': None,
#      'mislabeling': 0.0,
#      'created_at': '2024-07-09T03:41:35.558007Z',
#      'updated_at': '2024-07-09T03:41:35.558026Z',
#      'model': None,
#      'model_run': None,
#      'task': 996,
#      'project': 5},
#     'result_count': 0,
#     'unique_id': '0d0b630d-6fb9-4810-b40e-033eb92d7536',
#     'import_id': None,
#     'last_action': None,
#     'task': 996,
#     'project': 5,
#     'updated_by': 1,
#     'parent_prediction': 3091,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '4470607a-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [3091],
#   'data': {'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.'},
#   'meta': {},
#   'created_at': '2024-07-09T03:41:35.544861Z',
#   'updated_at': '2024-07-09T03:42:06.591358Z',
#   'inner_id': 1,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 5,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 997,
#   'annotations': [{'id': 16,
#     'completed_by': 1,
#     'result': [{'value': {'start': 10,
#        'end': 33,
#        'text': 'sandwiches (nearing $7)',
#        'labels': ['PRICE']},
#       'id': 'LdVgmN9E7v',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'manual'},
#      {'value': {'start': 10,
#        'end': 80,
#        'text': "sandwiches (nearing $7) didn't come with anything like chips or a side",
#        'labels': ['FOOD']},
#       'id': 'E_SBnraY5F',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-09T03:42:25.003821Z',
#     'updated_at': '2024-07-09T03:42:25.003842Z',
#     'draft_created_at': '2024-07-09T03:42:18.149852Z',
#     'lead_time': 16.846,
#     'prediction': {'id': 3092,
#      'model_version': 'one',
#      'created_ago': '0\xa0minutes',
#      'result': [{'id': '58e6528f-f285-42b5-a760-7b197b095328',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 65,
#         'end': 80,
#         'score': 0.6,
#         'text': 'chips or a side',
#         'labels': ['FOOD']}}],
#      'score': 0.6,
#      'cluster': None,
#      'neighbors': None,
#      'mislabeling': 0.0,
#      'created_at': '2024-07-09T03:41:35.558060Z',
#      'updated_at': '2024-07-09T03:41:35.558069Z',
#      'model': None,
#      'model_run': None,
#      'task': 997,
#      'project': 5},
#     'result_count': 0,
#     'unique_id': '4d349e70-4fe1-4c5c-a6e2-934498b7a783',
#     'import_id': None,
#     'last_action': None,
#     'task': 997,
#     'project': 5,
#     'updated_by': 1,
#     'parent_prediction': 3092,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '4470607a-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [3092],
#   'data': {'text': "Also, the sandwiches (nearing $7) didn't come with anything like chips or a side."},
#   'meta': {},
#   'created_at': '2024-07-09T03:41:35.544930Z',
#   'updated_at': '2024-07-09T03:42:25.088664Z',
#   'inner_id': 2,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 5,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 998,
#   'annotations': [{'id': 17,
#     'completed_by': 1,
#     'result': [{'value': {'start': 30,
#        'end': 66,
#        'text': 'BBQ Salmon, Sea Bass and Crispy Duck',
#        'labels': ['FOOD']},
#       'id': '5bfb2456-191e-4839-b702-06a98cde7092',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-09T03:42:28.488001Z',
#     'updated_at': '2024-07-09T03:42:28.488028Z',
#     'draft_created_at': None,
#     'lead_time': 2.377,
#     'prediction': {'id': 3093,
#      'model_version': 'one',
#      'created_ago': '0\xa0minutes',
#      'result': [{'id': '5bfb2456-191e-4839-b702-06a98cde7092',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 30,
#         'end': 66,
#         'score': 0.8,
#         'text': 'BBQ Salmon, Sea Bass and Crispy Duck',
#         'labels': ['FOOD']}}],
#      'score': 0.8,
#      'cluster': None,
#      'neighbors': None,
#      'mislabeling': 0.0,
#      'created_at': '2024-07-09T03:41:35.558097Z',
#      'updated_at': '2024-07-09T03:41:35.558105Z',
#      'model': None,
#      'model_run': None,
#      'task': 998,
#      'project': 5},
#     'result_count': 0,
#     'unique_id': '35daf80a-315f-4883-9459-a7f589de69ab',
#     'import_id': None,
#     'last_action': None,
#     'task': 998,
#     'project': 5,
#     'updated_by': 1,
#     'parent_prediction': 3093,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '4470607a-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [3093],
#   'data': {'text': 'Luckily we saved room for the BBQ Salmon, Sea Bass and Crispy Duck.'},
#   'meta': {},
#   'created_at': '2024-07-09T03:41:35.544976Z',
#   'updated_at': '2024-07-09T03:42:28.557703Z',
#   'inner_id': 3,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 5,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 999,
#   'annotations': [{'id': 18,
#     'completed_by': 1,
#     'result': [{'value': {'start': 0,
#        'end': 39,
#        'text': "I've been to Naples 45 for dinner twice",
#        'labels': ['SERVICE']},
#       'id': '27ONhCcL4H',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-09T03:42:43.404741Z',
#     'updated_at': '2024-07-09T03:42:43.404763Z',
#     'draft_created_at': None,
#     'lead_time': 13.765,
#     'prediction': {'id': 3094,
#      'model_version': 'one',
#      'created_ago': '1\xa0minute',
#      'result': [{'id': '99784d39-56f7-48cf-a524-68450d335e0f',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 5,
#         'end': 33,
#         'score': 0.4,
#         'text': 'been to Naples 45 for dinner',
#         'labels': ['SERVICE']}},
#       {'id': 'd30a966e-a75b-40f1-98f5-c55083f6655d',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 34,
#         'end': 39,
#         'score': 0.3,
#         'text': 'twice',
#         'labels': ['SERVICE']}}],
#      'score': 0.35,
#      'cluster': None,
#      'neighbors': None,
#      'mislabeling': 0.0,
#      'created_at': '2024-07-09T03:41:35.558136Z',
#      'updated_at': '2024-07-09T03:41:35.558144Z',
#      'model': None,
#      'model_run': None,
#      'task': 999,
#      'project': 5},
#     'result_count': 0,
#     'unique_id': '9a302784-c649-43e8-8f7d-77584f7a5787',
#     'import_id': None,
#     'last_action': None,
#     'task': 999,
#     'project': 5,
#     'updated_by': 1,
#     'parent_prediction': 3094,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '4470607a-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [3094],
#   'data': {'text': "I've been to Naples 45 for dinner twice."},
#   'meta': {},
#   'created_at': '2024-07-09T03:41:35.545019Z',
#   'updated_at': '2024-07-09T03:42:43.481617Z',
#   'inner_id': 4,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 5,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 1000,
#   'annotations': [{'id': 19,
#     'completed_by': 1,
#     'result': [{'value': {'start': 5,
#        'end': 27,
#        'text': 'serves very fresh fish',
#        'labels': ['FOOD']},
#       'id': 'ae24fb26-db42-4f36-b4e7-499e03ecf5b8',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 35,
#        'end': 58,
#        'text': 'trendy, modern ambiance',
#        'labels': ['AMBIENCE']},
#       'id': '0d860b09-c825-4995-b51d-7cb3653d956c',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 60,
#        'end': 95,
#        'text': 'prime location on Park Avenue South',
#        'labels': ['LOCATION']},
#       'id': 'fa777f0f-7349-47c5-b222-1beff4854314',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 100,
#        'end': 116,
#        'text': 'friendly service',
#        'labels': ['SERVICE']},
#       'id': '59ce84e4-132b-41d2-b6c5-c1f2187cdc0d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-09T03:42:51.377347Z',
#     'updated_at': '2024-07-09T03:42:51.377369Z',
#     'draft_created_at': None,
#     'lead_time': 6.951,
#     'prediction': {'id': 3095,
#      'model_version': 'one',
#      'created_ago': '1\xa0minute',
#      'result': [{'id': 'ae24fb26-db42-4f36-b4e7-499e03ecf5b8',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 5,
#         'end': 27,
#         'score': 0.7,
#         'text': 'serves very fresh fish',
#         'labels': ['FOOD']}},
#       {'id': '0d860b09-c825-4995-b51d-7cb3653d956c',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 35,
#         'end': 58,
#         'score': 0.6,
#         'text': 'trendy, modern ambiance',
#         'labels': ['AMBIENCE']}},
#       {'id': 'fa777f0f-7349-47c5-b222-1beff4854314',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 60,
#         'end': 95,
#         'score': 0.8,
#         'text': 'prime location on Park Avenue South',
#         'labels': ['LOCATION']}},
#       {'id': '59ce84e4-132b-41d2-b6c5-c1f2187cdc0d',
#        'from_name': 'label',
#        'to_name': 'text',
#        'type': 'labels',
#        'value': {'start': 100,
#         'end': 116,
#         'score': 0.9,
#         'text': 'friendly service',
#         'labels': ['SERVICE']}}],
#      'score': 0.7499999999999999,
#      'cluster': None,
#      'neighbors': None,
#      'mislabeling': 0.0,
#      'created_at': '2024-07-09T03:41:35.558181Z',
#      'updated_at': '2024-07-09T03:41:35.558189Z',
#      'model': None,
#      'model_run': None,
#      'task': 1000,
#      'project': 5},
#     'result_count': 0,
#     'unique_id': 'c5880704-d2ea-4da7-ade4-0dba3dc84aa2',
#     'import_id': None,
#     'last_action': None,
#     'task': 1000,
#     'project': 5,
#     'updated_by': 1,
#     'parent_prediction': 3095,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '4470607a-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [3095],
#   'data': {'text': 'Haru serves very fresh fish, has a trendy, modern ambiance, prime location on Park Avenue South and friendly service.'},
#   'meta': {},
#   'created_at': '2024-07-09T03:41:35.545060Z',
#   'updated_at': '2024-07-09T03:42:51.454236Z',
#   'inner_id': 5,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 5,
#   'updated_by': 1,
#   'comment_authors': []}]

# %%
holdout_raw[0]
# Out:
# {'id': 996,
#  'annotations': [{'id': 15,
#    'completed_by': 1,
#    'result': [{'value': {'start': 15,
#       'end': 51,
#       'text': 'looks out over beautiful green lawns',
#       'labels': ['VIEW']},
#      'id': '780b56b2-376f-4afb-b7ac-df001a0ae76e',
#      'from_name': 'label',
#      'to_name': 'text',
#      'type': 'labels',
#      'origin': 'prediction'},
#     {'value': {'start': 59,
#       'end': 97,
#       'text': 'Hudson River and the Statue of Liberty',
#       'labels': ['VIEW']},
#      'id': 'bc96d157-1925-4b9a-8d5b-7a420b4fede2',
#      'from_name': 'label',
#      'to_name': 'text',
#      'type': 'labels',
#      'origin': 'prediction'}],
#    'was_cancelled': False,
#    'ground_truth': False,
#    'created_at': '2024-07-09T03:42:06.515569Z',
#    'updated_at': '2024-07-09T03:42:06.515591Z',
#    'draft_created_at': None,
#    'lead_time': 25.821,
#    'prediction': {'id': 3091,
#     'model_version': 'one',
#     'created_ago': '0\xa0minutes',
#     'result': [{'id': '780b56b2-376f-4afb-b7ac-df001a0ae76e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 15,
#        'end': 51,
#        'score': 0.7,
#        'text': 'looks out over beautiful green lawns',
#        'labels': ['VIEW']}},
#      {'id': 'bc96d157-1925-4b9a-8d5b-7a420b4fede2',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 59,
#        'end': 97,
#        'score': 0.8,
#        'text': 'Hudson River and the Statue of Liberty',
#        'labels': ['VIEW']}}],
#     'score': 0.75,
#     'cluster': None,
#     'neighbors': None,
#     'mislabeling': 0.0,
#     'created_at': '2024-07-09T03:41:35.558007Z',
#     'updated_at': '2024-07-09T03:41:35.558026Z',
#     'model': None,
#     'model_run': None,
#     'task': 996,
#     'project': 5},
#    'result_count': 0,
#    'unique_id': '0d0b630d-6fb9-4810-b40e-033eb92d7536',
#    'import_id': None,
#    'last_action': None,
#    'task': 996,
#    'project': 5,
#    'updated_by': 1,
#    'parent_prediction': 3091,
#    'parent_annotation': None,
#    'last_created_by': None}],
#  'file_upload': '4470607a-llm_extract_output_20240706095040_100_sample_label_studio.json',
#  'drafts': [],
#  'predictions': [3091],
#  'data': {'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.'},
#  'meta': {},
#  'created_at': '2024-07-09T03:41:35.544861Z',
#  'updated_at': '2024-07-09T03:42:06.591358Z',
#  'inner_id': 1,
#  'total_annotations': 1,
#  'cancelled_annotations': 0,
#  'total_predictions': 1,
#  'comment_count': 0,
#  'unresolved_comment_count': 0,
#  'last_comment_updated_at': None,
#  'project': 5,
#  'updated_by': 1,
#  'comment_authors': []}

# %% [markdown]
# # Load all data

# %%
LLM_OUTPUT_REWRITE_FP = f'../data/output/llm_extract_output_{VERSION}_rewrited.json'

with open(LLM_OUTPUT_REWRITE_FP, 'r') as f:
    llm_output = json.load(f)

# %%
# Unnest the record since each record contains 10 items (each llm prompt contains 10 inputs)
llm_output_raw = []
for record in llm_output:
    llm_output_raw.extend(list(record.values()))

# %%
llm_output_raw[:5]
# Out:
# [{'text': 'The service is not consistently excellent -- just decent.',
#   'entities': [['service is not consistently excellent', 'SERVICE', 0.4, -0.3],
#    ['just decent', 'SERVICE', 0.5, 0.2]]},
#  {'text': "I went with 5 friends and we lingered at the table for a bit and didn't feel rushed at all even though there was a wait.",
#   'entities': [["didn't feel rushed", 'AMBIENCE', 0.6, 0.4]]},
#  {'text': 'Food was very good as well, considering that we tried the budget selection (though I wish the pork belly that I ordered was roasted a bit longer, so that fat was more of a melt-in-your-mouth experience).',
#   'entities': [['food was very good', 'FOOD', 0.7, 0.5],
#    ['pork belly that I ordered', 'FOOD', 0.6, -0.2]]},
#  {'text': 'It is about FOOD and Ambiance, and imagine how dreadful it will be if we only had to listen to an idle engine.',
#   'entities': [['about FOOD and Ambiance', 'AMBIENCE', 0.5, 0.3],
#    ['listen to an idle engine', 'AMBIENCE', 0.4, -0.6]]},
#  {'text': 'The bartender on my most recent visit was so incredibly rude that I will never go back.',
#   'entities': [['bartender was rude', 'SERVICE', 0.3, -0.7]]}]

# %% [markdown]
# # Convert holdout label studio format to SpaCy JSON format

# %%
from src.convert_ner_format.label_studio_to_spacy import convert_label_studio_to_spacy_format

# %%
holdout_spacy = convert_label_studio_to_spacy_format(holdout_raw)

# %%
holdout_spacy[:5]
# Out:
# [{'id': '53745975096161334446695170010345366844',
#   'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.',
#   'label': [[15, 51, 'VIEW'], [59, 97, 'VIEW']],
#   'Comments': []},
#  {'id': '14008356808251230170256576349676573112',
#   'text': "Also, the sandwiches (nearing $7) didn't come with anything like chips or a side.",
#   'label': [[10, 33, 'PRICE'], [10, 80, 'FOOD']],
#   'Comments': []},
#  {'id': '196846222781357184059657962635349503302',
#   'text': 'Luckily we saved room for the BBQ Salmon, Sea Bass and Crispy Duck.',
#   'label': [[30, 66, 'FOOD']],
#   'Comments': []},
#  {'id': '122902927917699489714278789756481778575',
#   'text': "I've been to Naples 45 for dinner twice.",
#   'label': [[0, 39, 'SERVICE']],
#   'Comments': []},
#  {'id': '209028716300947491053334478581226250868',
#   'text': 'Haru serves very fresh fish, has a trendy, modern ambiance, prime location on Park Avenue South and friendly service.',
#   'label': [[5, 27, 'FOOD'],
#    [35, 58, 'AMBIENCE'],
#    [60, 95, 'LOCATION'],
#    [100, 116, 'SERVICE']],
#   'Comments': []}]

# %%
# Persist
holdout_spacy_fp = "../data/output/llm_extract_output_holdout_spacy.json"
with open(holdout_spacy_fp, "w") as f:
    json.dump(holdout_spacy, f)

# %% [markdown]
# # Convert LLM Output to Spacy JSON format

# %%
from src.convert_ner_format.llm_output_to_spacy import convert_from_llm_output_to_spacy

# %%
llm_output_spacy = convert_from_llm_output_to_spacy(llm_output_raw)
# Out:
# 2024-07-09 10:57:51.400 | INFO     | src.utils.time.timer:timed:23 - convert_from_llm_output_to_spacy runtime: 0.007s

# %%
len(llm_output_spacy)
# Out:
# 1998

# %%
llm_output_spacy[:5]
# Out:
# [{'id': '251698800132815913556804367643027318268',
#   'text': 'The service is not consistently excellent -- just decent.',
#   'label': [[4, 41, 'SERVICE'], [45, 56, 'SERVICE']],
#   'Comments': []},
#  {'id': '220536303835705033511694647871179001291',
#   'text': "I went with 5 friends and we lingered at the table for a bit and didn't feel rushed at all even though there was a wait.",
#   'label': [[65, 83, 'AMBIENCE']],
#   'Comments': []},
#  {'id': '159991645213750204725390416162905872638',
#   'text': 'Food was very good as well, considering that we tried the budget selection (though I wish the pork belly that I ordered was roasted a bit longer, so that fat was more of a melt-in-your-mouth experience).',
#   'label': [[94, 119, 'FOOD']],
#   'Comments': []},
#  {'id': '129042515009119996187744609637264735274',
#   'text': 'It is about FOOD and Ambiance, and imagine how dreadful it will be if we only had to listen to an idle engine.',
#   'label': [[6, 29, 'AMBIENCE'], [85, 109, 'AMBIENCE']],
#   'Comments': []},
#  {'id': '142561611578058641069894873159556652784',
#   'text': 'The bartender on my most recent visit was so incredibly rude that I will never go back.',
#   'label': [],
#   'Comments': []}]

# %%
# Persist
llm_output_spacy_fp = f"../data/output/llm_extract_output_{VERSION}_spacy.json"
with open(llm_output_spacy_fp, "w") as f:
    json.dump(llm_output_spacy, f)
