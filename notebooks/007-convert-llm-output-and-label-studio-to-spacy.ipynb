# %% [markdown]
# # Set up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

# %%
import sys
sys.path.insert(0, '..')

# %% [markdown]
# # Load holdout label studio data

# %%
HOLDOUT_LABEL_STUDIO_FP = '../data/output/llm_extract_output_holdout_label_studio.json'
with open(HOLDOUT_LABEL_STUDIO_FP, 'r') as f:
    holdout_raw = json.load(f)

# %%
holdout_raw[:5]
# Out:
# [{'id': 2,
#   'annotations': [{'id': 1,
#     'completed_by': 1,
#     'result': [{'value': {'start': 15,
#        'end': 51,
#        'text': 'looks out over beautiful green lawns',
#        'labels': ['VIEW']},
#       'id': '929ab575-1749-496f-8379-fc3f5d2291b3',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 59,
#        'end': 97,
#        'text': 'Hudson River and the Statue of Liberty',
#        'labels': ['VIEW']},
#       'id': 'ab805581-7b2c-4d50-b9d3-461afc8bf341',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-08T10:19:53.224346Z',
#     'updated_at': '2024-07-08T10:19:53.224373Z',
#     'draft_created_at': None,
#     'lead_time': 7.335,
#     'prediction': {},
#     'result_count': 0,
#     'unique_id': '3bc9c7a8-5fe8-40e9-b785-9320564f903b',
#     'import_id': None,
#     'last_action': None,
#     'task': 2,
#     'project': 1,
#     'updated_by': 1,
#     'parent_prediction': 1997,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '01c1a5c8-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [1997],
#   'data': {'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.'},
#   'meta': {},
#   'created_at': '2024-07-08T10:18:46.611778Z',
#   'updated_at': '2024-07-08T10:19:53.299292Z',
#   'inner_id': 1,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 1,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 3,
#   'annotations': [{'id': 2,
#     'completed_by': 1,
#     'result': [{'value': {'start': 10,
#        'end': 33,
#        'text': 'sandwiches (nearing $7)',
#        'labels': ['PRICE']},
#       'id': 'BoMB2ivxx1',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'manual'},
#      {'value': {'start': 10,
#        'end': 80,
#        'text': "sandwiches (nearing $7) didn't come with anything like chips or a side",
#        'labels': ['FOOD']},
#       'id': '-xaoevEfI0',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-08T10:20:24.290517Z',
#     'updated_at': '2024-07-08T10:21:11.290370Z',
#     'draft_created_at': '2024-07-08T10:20:23.201065Z',
#     'lead_time': 53.721000000000004,
#     'prediction': {},
#     'result_count': 0,
#     'unique_id': '8ff4c819-d4c5-481d-8c3a-a7995708df6b',
#     'import_id': None,
#     'last_action': None,
#     'task': 3,
#     'project': 1,
#     'updated_by': 1,
#     'parent_prediction': 1998,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '01c1a5c8-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [1998],
#   'data': {'text': "Also, the sandwiches (nearing $7) didn't come with anything like chips or a side."},
#   'meta': {},
#   'created_at': '2024-07-08T10:18:46.611850Z',
#   'updated_at': '2024-07-08T10:21:11.402380Z',
#   'inner_id': 2,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 1,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 4,
#   'annotations': [{'id': 3,
#     'completed_by': 1,
#     'result': [{'value': {'start': 30,
#        'end': 66,
#        'text': 'BBQ Salmon, Sea Bass and Crispy Duck',
#        'labels': ['FOOD']},
#       'id': '4a784863-a4e3-4161-82f3-6d8bc7722cf2',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-08T11:18:05.041872Z',
#     'updated_at': '2024-07-08T11:18:05.041898Z',
#     'draft_created_at': None,
#     'lead_time': 15.889,
#     'prediction': {},
#     'result_count': 0,
#     'unique_id': '4e491ec9-d1fc-4b9b-b943-7f9975256b84',
#     'import_id': None,
#     'last_action': None,
#     'task': 4,
#     'project': 1,
#     'updated_by': 1,
#     'parent_prediction': 1999,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '01c1a5c8-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [1999],
#   'data': {'text': 'Luckily we saved room for the BBQ Salmon, Sea Bass and Crispy Duck.'},
#   'meta': {},
#   'created_at': '2024-07-08T10:18:46.611896Z',
#   'updated_at': '2024-07-08T11:18:05.116260Z',
#   'inner_id': 3,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 1,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 5,
#   'annotations': [{'id': 4,
#     'completed_by': 1,
#     'result': [{'value': {'start': 0,
#        'end': 39,
#        'text': "I've been to Naples 45 for dinner twice",
#        'labels': ['SERVICE']},
#       'id': 'wc64uvV8vy',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-08T11:18:57.042957Z',
#     'updated_at': '2024-07-08T11:18:57.042976Z',
#     'draft_created_at': '2024-07-08T11:18:25.468858Z',
#     'lead_time': 50.511,
#     'prediction': {},
#     'result_count': 0,
#     'unique_id': 'b11a43e7-382e-4bb0-98f4-3ae5bfbee89f',
#     'import_id': None,
#     'last_action': None,
#     'task': 5,
#     'project': 1,
#     'updated_by': 1,
#     'parent_prediction': 2000,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '01c1a5c8-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [2000],
#   'data': {'text': "I've been to Naples 45 for dinner twice."},
#   'meta': {},
#   'created_at': '2024-07-08T10:18:46.611939Z',
#   'updated_at': '2024-07-08T11:18:57.118131Z',
#   'inner_id': 4,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 1,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 6,
#   'annotations': [{'id': 5,
#     'completed_by': 1,
#     'result': [{'value': {'start': 5,
#        'end': 27,
#        'text': 'serves very fresh fish',
#        'labels': ['FOOD']},
#       'id': 'e84f2c8c-8334-4c3d-a0f8-f8a38879111f',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 35,
#        'end': 58,
#        'text': 'trendy, modern ambiance',
#        'labels': ['AMBIENCE']},
#       'id': 'df708dce-c324-46ac-a1f9-a17f36500f56',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 60,
#        'end': 95,
#        'text': 'prime location on Park Avenue South',
#        'labels': ['LOCATION']},
#       'id': '557d2ed3-2bc5-4619-846b-ef6b080c27b3',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'},
#      {'value': {'start': 100,
#        'end': 116,
#        'text': 'friendly service',
#        'labels': ['SERVICE']},
#       'id': 'd47e5de6-7467-43cf-a0dd-bf3d80273e7a',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'origin': 'prediction'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2024-07-08T11:19:11.074256Z',
#     'updated_at': '2024-07-08T11:19:11.074282Z',
#     'draft_created_at': None,
#     'lead_time': 12.607,
#     'prediction': {},
#     'result_count': 0,
#     'unique_id': 'c83abe5a-7299-483c-b08f-d7b743842cc1',
#     'import_id': None,
#     'last_action': None,
#     'task': 6,
#     'project': 1,
#     'updated_by': 1,
#     'parent_prediction': 2001,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '01c1a5c8-llm_extract_output_20240706095040_100_sample_label_studio.json',
#   'drafts': [],
#   'predictions': [2001],
#   'data': {'text': 'Haru serves very fresh fish, has a trendy, modern ambiance, prime location on Park Avenue South and friendly service.'},
#   'meta': {},
#   'created_at': '2024-07-08T10:18:46.611980Z',
#   'updated_at': '2024-07-08T11:19:11.148707Z',
#   'inner_id': 5,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 1,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 1,
#   'updated_by': 1,
#   'comment_authors': []}]

# %%
holdout_raw[0]
# Out:
# {'id': 2,
#  'annotations': [{'id': 1,
#    'completed_by': 1,
#    'result': [{'value': {'start': 15,
#       'end': 51,
#       'text': 'looks out over beautiful green lawns',
#       'labels': ['VIEW']},
#      'id': '929ab575-1749-496f-8379-fc3f5d2291b3',
#      'from_name': 'label',
#      'to_name': 'text',
#      'type': 'labels',
#      'origin': 'prediction'},
#     {'value': {'start': 59,
#       'end': 97,
#       'text': 'Hudson River and the Statue of Liberty',
#       'labels': ['VIEW']},
#      'id': 'ab805581-7b2c-4d50-b9d3-461afc8bf341',
#      'from_name': 'label',
#      'to_name': 'text',
#      'type': 'labels',
#      'origin': 'prediction'}],
#    'was_cancelled': False,
#    'ground_truth': False,
#    'created_at': '2024-07-08T10:19:53.224346Z',
#    'updated_at': '2024-07-08T10:19:53.224373Z',
#    'draft_created_at': None,
#    'lead_time': 7.335,
#    'prediction': {},
#    'result_count': 0,
#    'unique_id': '3bc9c7a8-5fe8-40e9-b785-9320564f903b',
#    'import_id': None,
#    'last_action': None,
#    'task': 2,
#    'project': 1,
#    'updated_by': 1,
#    'parent_prediction': 1997,
#    'parent_annotation': None,
#    'last_created_by': None}],
#  'file_upload': '01c1a5c8-llm_extract_output_20240706095040_100_sample_label_studio.json',
#  'drafts': [],
#  'predictions': [1997],
#  'data': {'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.'},
#  'meta': {},
#  'created_at': '2024-07-08T10:18:46.611778Z',
#  'updated_at': '2024-07-08T10:19:53.299292Z',
#  'inner_id': 1,
#  'total_annotations': 1,
#  'cancelled_annotations': 0,
#  'total_predictions': 1,
#  'comment_count': 0,
#  'unresolved_comment_count': 0,
#  'last_comment_updated_at': None,
#  'project': 1,
#  'updated_by': 1,
#  'comment_authors': []}

# %% [markdown]
# # Load all data

# %%
LLM_ASPECTS_EXTRACT_FP = '../data/output/llm_extract_output_20240706095040.jsonl'

with open(LLM_ASPECTS_EXTRACT_FP, 'r') as f:
    all_data = [json.loads(jline) for jline in f.readlines()]

# %%
all_data_core = [record['record']['extra']['llm_extracted'] for record in all_data]
all_data_core[:5]
# Out:
# [{'1': {'text': 'The service is not consistently excellent -- just decent.',
#    'entities': [['service is not consistently excellent',
#      'SERVICE',
#      0.4,
#      -0.3],
#     ['just decent', 'SERVICE', 0.5, 0.2]]},
#   '2': {'text': "I went with 5 friends and we lingered at the table for a bit and didn't feel rushed at all even though there was a wait.",
#    'entities': [["didn't feel rushed", 'AMBIENCE', 0.6, 0.4]]},
#   '3': {'text': 'Food was very good as well, considering that we tried the budget selection (though I wish the pork belly that I ordered was roasted a bit longer, so that fat was more of a melt-in-your-mouth experience).',
#    'entities': [['food was very good', 'FOOD', 0.7, 0.5],
#     ['pork belly that I ordered', 'FOOD', 0.6, -0.2]]},
#   '4': {'text': 'It is about FOOD and Ambiance, and imagine how dreadful it will be if we only had to listen to an idle engine.',
#    'entities': [['about FOOD and Ambiance', 'AMBIENCE', 0.5, 0.3],
#     ['listen to an idle engine', 'AMBIENCE', 0.4, -0.6]]},
#   '5': {'text': 'The bartender on my most recent visit was so incredibly rude that I will never go back.',
#    'entities': [['bartender was rude', 'SERVICE', 0.3, -0.7]]},
#   '6': {'text': 'In such a crappy part of town to find a good value for lunch, this place is great.',
#    'entities': [['good value for lunch', 'FOOD', 0.8, 0.5],
#     ['great', 'OVERALL', 0.7, 0.4]]},
#   '7': {'text': "This is the only Thai place I go too in NYC, it's wonderful, and live relaxed Jazz on certain nights.",
#    'entities': [['only Thai place', 'FOOD', 0.6, 0.3],
#     ['live relaxed Jazz', 'AMBIENCE', 0.7, 0.4]]},
#   '8': {'text': 'After a seafood craving, i checked citysearch and chose to go to Fish based on a previous review and the citysearch info.',
#    'entities': [['seafood craving', 'FOOD', 0.5, -0.2],
#     ['citysearch info', 'SERVICE', 0.6, 0.3]]},
#   '9': {'text': 'Shockingly easy to throw a group dinner here: simple contract, deposit only to hold the date the entire 2nd fl mezz for our grp of 20.',
#    'entities': [['easy to throw a group dinner', 'SERVICE', 0.8, 0.6]]},
#   '10': {'text': "But they don't have a toaster, which is strange.",
#    'entities': [["don't have a toaster", 'FOOD', 0.4, -0.5]]}},
#  {'11': {'text': "I don't know about you guys, but when I go somewhere to eat I go for the food not for the atmosphere.",
#    'entities': [['food', 'FOOD', 0.8, 0.6]]},
#   '12': {'text': 'The fish is fresh and each piece is sliced to perfection and seasoned by the sushi chef (usually with a little fresh wasabi and soy sauce but also sometimes with some sea salt).',
#    'entities': [['fish is fresh', 'FOOD', 0.7, 0.5],
#     ['sliced to perfection', 'FOOD', 0.6, 0.4],
#     ['seasoned by the sushi chef', 'SERVICE', 0.8, 0.3]]},
#   '13': {'text': 'What makes this restaurant special are the authentic sichuan cooking and being the only one in NYC that offers authentic chongqing hotpot.',
#    'entities': [['authentic sichuan cooking', 'FOOD', 0.9, 0.7],
#     ['authentic chongqing hotpot', 'FOOD', 0.8, 0.6]]},
#   '14': {'text': 'What generous portions!',
#    'entities': [['generous portions', 'FOOD', 0.9, 0.5]]},
#   '15': {'text': 'The service is good and ambience is good for a date or group outing.',
#    'entities': [['service is good', 'SERVICE', 0.8, 0.4],
#     ['ambience is good', 'AMBIENCE', 0.7, 0.3]]},
#   '16': {'text': 'The service is good and the resturant is clean.',
#    'entities': [['service is good', 'SERVICE', 0.8, 0.4],
#     ['resturant is clean', 'SERVICE', 0.7, 0.5]]},
#   '17': {'text': 'Although they do the typical what kind of water would you like questions the service was good and overall very relaxing to place to eat.',
#    'entities': [['service was good', 'SERVICE', 0.8, 0.4],
#     ['very relaxing', 'AMBIENCE', 0.7, 0.5]]},
#   '18': {'text': 'Had a late night dinner on a Saturday night.',
#    'entities': [['late night dinner', 'SERVICE', 0.6, -0.2],
#     ['Saturday night', 'AMBIENCE', 0.4, 0.1]]},
#   '19': {'text': 'Authentic Pakistani food.',
#    'entities': [['Pakistani food', 'FOOD', 0.9, 0.6]]},
#   '20': {'text': "So all I'm trying to say is this restaurant is by far the best thai food restaurant I've ever been to.",
#    'entities': [['best thai food restaurant', 'FOOD', 0.8, 0.5]]}},
#  {'1': {'text': 'Worse of all, $60 was erroneously added to our $80 bill.',
#    'entities': [['$60 was erroneously added', 'SERVICE', 0.7, -0.6]]},
#   '2': {'text': 'Salads were fantastic.',
#    'entities': [['salads were fantastic', 'FOOD', 0.8, 0.5]]},
#   '3': {'text': 'My first time there I happened not to like the Crab Croquette apt that i ordered and they were happy to change it for me without making no big deal.',
#    'entities': [['not to like the Crab Croquette', 'FOOD', 0.6, -0.4],
#     ['happy to change it for me', 'SERVICE', 0.7, 0.5]]},
#   '4': {'text': 'The food was very good, a great deal, and the place its self was great.',
#    'entities': [['food was very good', 'FOOD', 0.8, 0.6],
#     ['great deal', 'VALUE', 0.7, 0.4],
#     ['place its self was great', 'AMBIENCE', 0.9, 0.7]]},
#   '5': {'text': 'My husband had the mesclun, salmon, and ice cream and he enjoyed all 3 courses.',
#    'entities': [['mesclun, salmon, and ice cream', 'FOOD', 0.8, 0.6]]},
#   '6': {'text': 'Great spot, whether looking for a couple of drinks or quiet dinner.',
#    'entities': [['great spot', 'AMBIENCE', 0.9, 0.7],
#     ['couple of drinks or quiet dinner', 'BEVERAGE', 0.8, 0.5]]},
#   '7': {'text': "Last time I went here, the waitress didn't come back after taking our order.",
#    'entities': [["waitress didn't come back", 'SERVICE', 0.4, -0.6]]},
#   '8': {'text': 'The rest of the menu is limited by everything is good eats.',
#    'entities': [['rest of the menu is limited', 'FOOD', 0.5, -0.3],
#     ['everything is good eats', 'FOOD', 0.7, 0.4]]},
#   '9': {'text': 'Best dish is nori-wrapped tuna.',
#    'entities': [['best dish is nori-wrapped tuna', 'FOOD', 0.8, 0.6]]},
#   '10': {'text': 'The in-house lady DJ on Saturday nights has outrageously good taste in music, and moreover, takes requests.',
#    'entities': [['in-house lady DJ', 'AMBIENCE', 0.9, 0.7],
#     ['outrageously good taste in music', 'ENTERTAINMENT', 0.8, 0.6]]}},
#  {'1': {'text': 'I love to visit Murrays for my bagel fix.',
#    'entities': [['visit Murrays', 'SERVICE', 0.7, 0.5]]},
#   '2': {'text': "We didn't even see a menu, as our waiter described both the specials and the main dishes.",
#    'entities': [["didn't even see a menu", 'FOOD', 0.4, -0.3],
#     ['waiter described both the specials and the main dishes',
#      'SERVICE',
#      0.8,
#      0.6]]},
#   '3': {'text': 'Great pizza and fantastic service.',
#    'entities': [['pizza', 'FOOD', 0.9, 0.7],
#     ['fantastic service', 'SERVICE', 0.8, 0.5]]}},
#  {'1': {'text': "I've had the chicken with garlic sauce, chicken with black bean sauce, and hunan chicken.",
#    'entities': [['chicken with garlic sauce', 'FOOD', 0.7, 0.5],
#     ['chicken with black bean sauce', 'FOOD', 0.6, 0.4],
#     ['hunan chicken', 'FOOD', 0.6, 0.3]]},
#   '2': {'text': "We ate out in the back patio, which is worth it as it's cool and the music is hear well there.",
#    'entities': [['back patio', 'AMBIENCE', 0.7, 0.5],
#     ['cool', 'AMBIENCE', 0.6, 0.4],
#     ['music is hear well', 'AMBIENCE', 0.6, 0.3]]},
#   '3': {'text': 'Traditional French decour was pleasant though the hall was rather noisy - the restaurant was full and we had to raise our voices to be able to maintain a conversation.',
#    'entities': [['Traditional French decour', 'AMBIENCE', 0.6, 0.4],
#     ['hall was rather noisy', 'AMBIENCE', 0.5, -0.5]]},
#   '4': {'text': 'Each table has a pot of boiling water sunken into its surface, and you get platters of thin sliced meats, various vegetables, and rice and glass noodles.',
#    'entities': [['pot of boiling water', 'SERVICE', 0.6, 0.3],
#     ['thin sliced meats', 'FOOD', 0.7, 0.5],
#     ['various vegetables', 'FOOD', 0.6, 0.4],
#     ['rice and glass noodles', 'FOOD', 0.6, 0.3]]},
#   '5': {'text': 'We were worried we would have trouble getting in, but somehow managed to have a short wait.',
#    'entities': [['trouble getting in', 'SERVICE', 0.5, -0.4],
#     ['short wait', 'SERVICE', 0.6, 0.3]]},
#   '6': {'text': 'my personal favorite is an everything bagel with lox spread, but all the bagles are unbeliavably good.',
#    'entities': [['everything bagel with lox spread', 'FOOD', 0.8, 0.7],
#     ['all the bagles are unbeliavably good', 'FOOD', 0.9, 0.6]]},
#   '7': {'text': 'The man that was hosting promised to save a table for our party of 7, then sat a party of 2 at the very table he was saving (mean while there were boths open all around).',
#    'entities': [['promised to save a table', 'SERVICE', 0.4, -0.5],
#     ['party of 7', 'SERVICE', 0.6, 0.3]]},
#   '8': {'text': 'The main course had an average portion, and was decent overall.',
#    'entities': [['main course had an average portion', 'FOOD', 0.5, 0.2],
#     ['was decent overall', 'FOOD', 0.6, 0.3]]},
#   '9': {'text': 'The restaurant is rather small but we were lucky to get a table quickly.',
#    'entities': [['restaurant is rather small', 'AMBIENCE', 0.5, -0.4],
#     ['lucky to get a table quickly', 'SERVICE', 0.6, 0.3]]},
#   '10': {'text': 'It is nearly impossible to get a table, so if you ever have the chance to go here for dinner, DO NOT pass it up.',
#    'entities': [['nearly impossible to get a table', 'SERVICE', 0.4, -0.6],
#     ['DO NOT pass it up', 'RECOMMENDATION', 0.9, 0.7]]}}]

# %% [markdown]
# # Convert holdout label studio format to SpaCy JSON format

# %%
from src.convert_ner_format.label_studio_to_spacy import convert_label_studio_to_spacy_format

# %%
holdout_spacy = convert_label_studio_to_spacy_format(holdout_raw)

# %%
holdout_spacy[:5]
# Out:
# [{'id': '53745975096161334446695170010345366844',
#   'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.',
#   'labels': [[15, 51, 'VIEW'], [59, 97, 'VIEW']],
#   'Comments': []},
#  {'id': '14008356808251230170256576349676573112',
#   'text': "Also, the sandwiches (nearing $7) didn't come with anything like chips or a side.",
#   'labels': [[10, 33, 'PRICE'], [10, 80, 'FOOD']],
#   'Comments': []},
#  {'id': '196846222781357184059657962635349503302',
#   'text': 'Luckily we saved room for the BBQ Salmon, Sea Bass and Crispy Duck.',
#   'labels': [[30, 66, 'FOOD']],
#   'Comments': []},
#  {'id': '122902927917699489714278789756481778575',
#   'text': "I've been to Naples 45 for dinner twice.",
#   'labels': [[0, 39, 'SERVICE']],
#   'Comments': []},
#  {'id': '209028716300947491053334478581226250868',
#   'text': 'Haru serves very fresh fish, has a trendy, modern ambiance, prime location on Park Avenue South and friendly service.',
#   'labels': [[5, 27, 'FOOD'],
#    [35, 58, 'AMBIENCE'],
#    [60, 95, 'LOCATION'],
#    [100, 116, 'SERVICE']],
#   'Comments': []}]

# %%
# Persist
holdout_spacy_fp = "../data/output/llm_extract_output_holdout_spacy.json"
with open(holdout_spacy_fp, "w") as f:
    json.dump(holdout_spacy, f)

# %% [markdown]
# # Convert LLM Output to Spacy JSON format

# %%
from src.convert_ner_format.llm_output_to_spacy import convert_from_llm_output_to_spacy

# %%
llm_output_spacy = convert_from_llm_output_to_spacy(all_data_core)

# %%
llm_output_spacy[:5]
# Out:
# [{'id': '251698800132815913556804367643027318268',
#   'text': 'The service is not consistently excellent -- just decent.',
#   'label': [[4, 41, 'SERVICE'], [45, 56, 'SERVICE']],
#   'Comments': []},
#  {'id': '268433312885968953427008844112012965196',
#   'text': "I don't know about you guys, but when I go somewhere to eat I go for the food not for the atmosphere.",
#   'label': [[73, 77, 'FOOD']],
#   'Comments': []},
#  {'id': '307992515862728360560151870227144964887',
#   'text': 'Worse of all, $60 was erroneously added to our $80 bill.',
#   'label': [[14, 39, 'SERVICE']],
#   'Comments': []},
#  {'id': '338784061477323240547457290851322993302',
#   'text': 'I love to visit Murrays for my bagel fix.',
#   'label': [[10, 23, 'SERVICE']],
#   'Comments': []},
#  {'id': '205690842130761920316860726724083097169',
#   'text': "I've had the chicken with garlic sauce, chicken with black bean sauce, and hunan chicken.",
#   'label': [[13, 38, 'FOOD'], [40, 69, 'FOOD'], [75, 88, 'FOOD']],
#   'Comments': []}]

# %%
# Persist
llm_output_spacy_fp = "../data/output/llm_extract_output_20240706095040_spacy.json"
with open(llm_output_spacy_fp, "w") as f:
    json.dump(llm_output_spacy, f)
