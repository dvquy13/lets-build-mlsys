# %% [markdown]
# # Set up

# %%
import json

# %% [markdown]
# # Load extraction results

# %%
LLM_ASPECTS_EXTRACT_FP = '../data/output/llm_extract_output_20240706095040.jsonl'

# %%
fp = LLM_ASPECTS_EXTRACT_FP
with open(fp, 'r') as f:
    results = [json.loads(jline) for jline in f.readlines()]

# %% [markdown]
# # Sample 100

# %%
import numpy as np
np.random.seed(41)

sampled = np.random.choice(results, 100)
sampled_extracted = [record['record']['extra']['llm_extracted'] for record in sampled]
sampled_extracted
# Out:
# [{'11': {'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.',
#    'entities': [['looks out over beautiful green lawns', 'VIEW', 0.7, 0.5],
#     ['Hudson River and the Statue of Liberty', 'VIEW', 0.8, 0.6]]},
#   '12': {'text': "Also, the sandwiches (nearing $7) didn't come with anything like chips or a side.",
#    'entities': [["sandwiches didn't come with anything", 'FOOD', 0.5, -0.4],
#     ['chips or a side', 'FOOD', 0.6, -0.3]]},
#   '13': {'text': 'Luckily we saved room for the BBQ Salmon, Sea Bass and Crispy Duck.',
#    'entities': [['BBQ Salmon, Sea Bass and Crispy Duck', 'FOOD', 0.8, 0.5]]},
#   '14': {'text': "I've been to Naples 45 for dinner twice.",
#    'entities': [['been to Naples 45 for dinner', 'SERVICE', 0.4, 0.2],
#     ['twice', 'SERVICE', 0.3, 0.1]]},
#   '15': {'text': 'Haru serves very fresh fish, has a trendy, modern ambiance, prime location on Park Avenue South and friendly service.',
#    'entities': [['serves very fresh fish', 'FOOD', 0.7, 0.4],
#     ['trendy, modern ambiance', 'AMBIENCE', 0.6, 0.3],
#     ['prime location on Park Avenue South', 'LOCATION', 0.8, 0.5],
#     ['friendly service', 'SERVICE', 0.9, 0.7]]},
#   '16': {'text': "At the end you're left with a mild broth with noodles that you can slurp out of a cup.",
#    'entities': [['mild broth with noodles', 'FOOD', 0.5, -0.2],
#     ['slurp out of a cup', 'SERVICE', 0.4, 0.1]]},
#   '17': {'text': 'The food inludes famous scrumptious bombay style chaat such as bhelpuri, sevpuri and samosa chaats, as well as other great indian appetizers.',
#    'entities': [['famous scrumptious bombay style chaat', 'FOOD', 0.8, 0.6],
#     ['bhelpuri, sevpuri and samosa chaats', 'FOOD', 0.7, 0.5]]},
#   '18': {'text': 'The food is delicious - from the specials to the regular menu-fare, the dishes are never a disappointment.',
#    'entities': [['food is delicious', 'FOOD', 0.9, 0.7],
#     ['specials to the regular menu-fare', 'FOOD', 0.8, 0.6]]},
#   '19': {'text': "they didn't disappoint, service from the second i arrived at the door was extremely pleasant and attentive with almost one server per table.",
#    'entities': [["didn't disappoint", 'SERVICE', 0.5, -0.2],
#     ['service from the second i arrived', 'SERVICE', 0.8, 0.6]]},
#   '20': {'text': "I think I've had some the best meals of my life at minnow.",
#    'entities': [['had some the best meals of my life', 'FOOD', 0.9, 0.8],
#     ['at minnow', 'LOCATION', 0.7, 0.4]]}},
#  {'1': {'text': 'stick with the chicken, beef, and lamb dishes.',
#    'entities': [['chicken', 'FOOD', 0.7, 0.4],
#     ['beef', 'FOOD', 0.6, 0.3],
#     ['lamb', 'FOOD', 0.5, 0.2]]},
#   '2': {'text': "Tried the pad see ew on the recommendation of the last reviewer since it's one of my favorite dishes.",
#    'entities': [['pad see ew', 'FOOD', 0.6, 0.4],
#     ['recommendation of the last reviewer', 'SERVICE', 0.5, 0.3]]},
#   '3': {'text': 'When you want a piece of beef, head on over.',
#    'entities': [['piece of beef', 'FOOD', 0.7, 0.4]]},
#   '4': {'text': 'Try green curry with vegetables.',
#    'entities': [['green curry', 'FOOD', 0.6, 0.3],
#     ['vegetables', 'FOOD', 0.5, 0.2]]},
#   '5': {'text': 'A++   The service was good to excellent along with the attitude.',
#    'entities': [['service was good to excellent', 'SERVICE', 0.7, 0.4],
#     ['attitude', 'SERVICE', 0.6, 0.3]]},
#   '6': {'text': "Don't expect to sit down inside though, there are only a few tables and they are always full.",
#    'entities': [['sit down inside', 'AMBIENCE', 0.4, -0.4],
#     ['few tables and they are always full', 'AMBIENCE', 0.3, -0.3]]},
#   '7': {'text': "The wine selection (by the glass and bottle) is wonderful and I always recommend that friends make a reservation if they're going to be in town.",
#    'entities': [['wine selection', 'BEVERAGE', 0.6, 0.4],
#     ['make a reservation', 'SERVICE', 0.5, 0.3]]},
#   '8': {'text': 'Such nice people working here - but I have to review the food.',
#    'entities': [['nice people working here', 'SERVICE', 0.7, 0.4]]},
#   '9': {'text': 'This is one of the best comfort food places in the city.',
#    'entities': [['comfort food places', 'FOOD', 0.6, 0.3]]},
#   '10': {'text': "Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!",
#    'entities': [['sake list', 'BEVERAGE', 0.5, 0.2],
#     ['Purple Haze', 'BEVERAGE', 0.4, -0.4]]}},
#  {'1': {'text': "Joe's Pizza used to have the best slice until this pizzeria opened up.",
#    'entities': [['best slice', 'FOOD', 0.6, 0.4],
#     ['this pizzeria opened up', 'SERVICE', 0.5, -0.2]]},
#   '2': {'text': 'I am happy i did the food was awsome.',
#    'entities': [['food was awsome', 'FOOD', 0.8, 0.6]]},
#   '3': {'text': 'in an effort to increase turnover, the restaurant offers no desserts beyond the complimentary espresso cup filled with chocolate mousse.',
#    'entities': [['no desserts', 'FOOD', 0.7, -0.5],
#     ['complimentary espresso cup filled with chocolate mousse',
#      'BEVERAGE',
#      0.6,
#      0.4]]},
#   '4': {'text': "They didn't give us the dinner special until we asked for it.",
#    'entities': [["didn't give us the dinner special", 'SERVICE', 0.5, -0.3],
#     ['until we asked for it', 'SERVICE', 0.6, 0.2]]},
#   '5': {'text': 'I fell in love with the egg noodles in the beef broth with shrimp dumplings and slices of BBQ roast pork.',
#    'entities': [['egg noodles in the beef broth with shrimp dumplings',
#      'FOOD',
#      0.8,
#      0.6],
#     ['slices of BBQ roast pork', 'FOOD', 0.7, 0.4]]},
#   '6': {'text': 'It was like the servers forgot that they actually worked there and instead wanted to hang out and be cool.',
#    'entities': [['servers forgot that they actually worked there',
#      'SERVICE',
#      0.5,
#      -0.5],
#     ['wanted to hang out and be cool', 'SERVICE', 0.4, -0.2]]},
#   '7': {'text': 'Other apetizers and food',
#    'entities': [['apetizers and food', 'FOOD', 0.6, 0.3]]},
#   '8': {'text': 'Service was also horrible and the ambience is not that great.',
#    'entities': [['service was also horrible', 'SERVICE', 0.5, -0.7],
#     ['ambience is not that great', 'AMBIENCE', 0.4, -0.6]]},
#   '9': {'text': 'I will recommend Scopa to all of my friends for a place to go for wonderful Italian food.',
#    'entities': [['recommend Scopa', 'SERVICE', 0.7, 0.5],
#     ['wonderful Italian food', 'FOOD', 0.8, 0.6]]},
#   '10': {'text': 'For many people, this may not seem like Aunthentic Thai food because most places in NYC arent quite authentic.',
#    'entities': [['Aunthentic Thai food', 'FOOD', 0.5, -0.3],
#     ['most places in NYC arent quite authentic', 'SERVICE', 0.4, -0.2]]}},
#  {'1': {'text': 'An excellent service',
#    'entities': [['excellent service', 'SERVICE', 0.8, 0.6]]},
#   '2': {'text': 'We had a wonderful meal at Naples 45 a month ago on a visit to NYC.',
#    'entities': []},
#   '3': {'text': 'The waitstaff were attentive, polite and helpful - an impressive feat in such close quarters.',
#    'entities': [['waitstaff were attentive', 'SERVICE', 0.7, 0.5],
#     ['polite and helpful', 'SERVICE', 0.8, 0.6]]},
#   '4': {'text': 'While Sapphire is certainly not lacking in ambiance, and probably has the best decor of any Indian restaurant I have been to in New York City, the food was not what I had hoped for.',
#    'entities': [['lacking in ambiance', 'AMBIENCE', 0.5, -0.2],
#     ['best decor', 'AMBIENCE', 0.6, 0.4],
#     ['food was not what I had hoped for', 'FOOD', 0.3, -0.5]]},
#   '5': {'text': 'It can be a little confusing as to where one goes to order, but once the food is ordered, you are in for a treat.',
#    'entities': []},
#   '6': {'text': 'And the Tom Kha soup was pathetic.',
#    'entities': [['Tom Kha soup', 'FOOD', 0.2, -0.7]]},
#   '7': {'text': 'I ordered the chu chu curry and my friend ordered the pad thai chicken.',
#    'entities': [['chu chu curry', 'FOOD', 0.5, 0.3],
#     ['pad thai chicken', 'FOOD', 0.6, 0.4]]},
#   '8': {'text': 'All the money went into the interior decoration, none of it went to the chefs.',
#    'entities': [['money went into the interior decoration',
#      'AMBIENCE',
#      0.3,
#      -0.5],
#     ['none of it went to the chefs', 'FOOD', 0.2, -0.7]]},
#   '9': {'text': 'Even though the restaurant was packed, we were seated promptly and even asked for a table upstairs with no problems.',
#    'entities': [['restaurant was packed', 'AMBIENCE', 0.5, -0.2],
#     ['seated promptly', 'SERVICE', 0.7, 0.4]]},
#   '10': {'text': 'The Pad Thai is excellent here, as well.',
#    'entities': [['Pad Thai is excellent', 'FOOD', 0.8, 0.6]]}},
#  {'11': {'text': "i don't usually order wine with indian so i can't comment on their wine list or their wines.",
#    'entities': [['wine list', 'BEVERAGE', 0.3, 0.0],
#     ['wines', 'BEVERAGE', 0.2, 0.0]]},
#   '12': {'text': 'My turkey burger was not cooked at all, my friends salmon was completely raw.',
#    'entities': [['turkey burger was not cooked', 'FOOD', 0.6, -0.8],
#     ['salmon was completely raw', 'FOOD', 0.5, -0.9]]},
#   '13': {'text': 'During our meal, the management came over and checked on us and even bought us a round of drinks.',
#    'entities': [['management came over and checked on us',
#      'SERVICE',
#      0.7,
#      0.4],
#     ['bought us a round of drinks', 'BEVERAGE', 0.6, 0.3]]},
#   '14': {'text': "They are the best bagels I've had.",
#    'entities': [["best bagels I've had", 'FOOD', 0.8, 0.5]]},
#   '15': {'text': 'The menu prices are a bit expensive for what you get in quality and portion size.',
#    'entities': [['menu prices are a bit expensive', 'SERVICE', 0.6, -0.4],
#     ['quality and portion size', 'FOOD', 0.5, -0.3]]},
#   '16': {'text': 'both are very reasonably priced (around $8 for dinner and $5 for lunch), and are delicious and filling.',
#    'entities': [['are very reasonably priced', 'SERVICE', 0.7, 0.4],
#     ['delicious and filling', 'FOOD', 0.6, 0.3]]},
#   '17': {'text': "We saw them heating up at least one frozen item though I'm not sure which dim sum dish it was.",
#    'entities': [['heating up a frozen item', 'FOOD', 0.5, -0.4]]},
#   '18': {'text': 'The menu changed, portions were even smaller than before, a lentil dish was salty beyond edibility, a basmati rice dish lacked flavor.',
#    'entities': [['menu changed', 'SERVICE', 0.6, -0.3],
#     ['portions were even smaller', 'FOOD', 0.5, -0.4],
#     ['lentil dish was salty beyond edibility', 'FOOD', 0.4, -0.7],
#     ['basmati rice dish lacked flavor', 'FOOD', 0.3, -0.6]]},
#   '19': {'text': 'The kitchen however, is almost always slow.',
#    'entities': [['kitchen is almost always slow', 'SERVICE', 0.5, -0.7]]},
#   '20': {'text': 'The plain slice is great and if you get toppings, the whole slice is topped with them, not sparsely sprinkled on like some places.',
#    'entities': [['plain slice is great', 'FOOD', 0.8, 0.5],
#     ['whole slice is topped with them', 'FOOD', 0.6, 0.3]]}},
#  {'1': {'text': "Perhaps this food is considered extreme to an Upper East Side resident, but for the rest of us who've actually eaten ethnic food, this is simply dull.",
#    'entities': [['this food', 'FOOD', 0.6, -0.5],
#     ['considered extreme', 'FOOD', 0.4, -0.3]]},
#   '2': {'text': 'The service is a little scatty at times but all is forgiven when the food arrives.',
#    'entities': [['service is a little scatty', 'SERVICE', 0.5, -0.4],
#     ['food arrives', 'FOOD', 0.7, 0.3]]},
#   '3': {'text': 'They sell special sushi, everything have a topping, sauce and etc.',
#    'entities': [['special sushi', 'FOOD', 0.8, 0.5],
#     ['topping, sauce and etc', 'FOOD', 0.6, 0.3]]},
#   '4': {'text': 'My biggest complaint was the un-tasty food although presented well.',
#    'entities': [['un-tasty food', 'FOOD', 0.5, -0.7],
#     ['presented well', 'SERVICE', 0.6, 0.3]]},
#   '5': {'text': 'Light, refreshing summer rolls (not fried) remind me of Vietnamese places in Paris.',
#    'entities': [['summer rolls', 'FOOD', 0.7, 0.4],
#     ['Vietnamese places in Paris', 'VIEW', 0.6, 0.3]]},
#   '6': {'text': 'We had champagne and caviar and felt like princesses!',
#    'entities': [['champagne and caviar', 'BEVERAGE', 0.8, 0.7],
#     ['felt like princesses', 'SERVICE', 0.5, 0.4]]},
#   '7': {'text': 'Admittedly some nights inside the restaurant were rather warm, but the open kitchen is part of the charm.',
#    'entities': [['some nights inside the restaurant were rather warm',
#      'AMBIENCE',
#      0.5,
#      -0.4],
#     ['open kitchen is part of the charm', 'SERVICE', 0.6, 0.3]]},
#   '8': {'text': 'I would highly recommand requesting a table by the window.',
#    'entities': [['requesting a table by the window', 'VIEW', 0.7, 0.4]]},
#   '9': {'text': 'Great friendly service, Fast seating, Fast Delivery, Excellent sushi.',
#    'entities': [['friendly service', 'SERVICE', 0.8, 0.5],
#     ['Fast seating', 'SERVICE', 0.6, 0.3],
#     ['Fast Delivery', 'SERVICE', 0.7, 0.4],
#     ['Excellent sushi', 'FOOD', 0.9, 0.6]]},
#   '10': {'text': 'And Kruno, the beverage manager is the best bartender I have yet to come across.',
#    'entities': [['Kruno, the beverage manager', 'SERVICE', 0.8, 0.5],
#     ['best bartender', 'BEVERAGE', 0.7, 0.4]]}},
#  {'1': {'text': "The waiters and owners were nonchalant about this and promised to call the exterminator but weren't as dismayed or apologetic as I would have expected.",
#    'entities': [['waiters and owners were nonchalant', 'SERVICE', 0.6, -0.4],
#     ['promised to call the exterminator', 'SERVICE', 0.5, -0.2],
#     ["weren't as dismayed or apologetic", 'SERVICE', 0.3, -0.3]]},
#   '2': {'text': 'Sake collection was excellent (Try Nanbu Bijin), but pricy.',
#    'entities': [['sake collection was excellent', 'BEVERAGE', 0.7, 0.5],
#     ['but pricy', 'BEVERAGE', 0.4, -0.3]]},
#   '3': {'text': 'Had 1 appetizer, 2 entrees and 2 cokes and the bill was ~$55.00, not including tip.',
#    'entities': [['had 1 appetizer', 'FOOD', 0.5, 0.2],
#     ['2 entrees', 'FOOD', 0.6, 0.3],
#     ['2 cokes', 'BEVERAGE', 0.4, 0.2],
#     ['bill was ~$55.00', 'SERVICE', 0.3, -0.1]]},
#   '4': {'text': 'Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).',
#    'entities': [['agreed favorite', 'FOOD', 0.7, 0.5],
#     ['orrechiete with sausage and chicken', 'FOOD', 0.6, 0.4]]},
#   '5': {'text': 'The place was nice and calm.',
#    'entities': [['place was nice and calm', 'AMBIENCE', 0.7, 0.3]]},
#   '6': {'text': 'The quail was fantastic and unique and the pastas were full of flavor.',
#    'entities': [['quail was fantastic and unique', 'FOOD', 0.8, 0.5],
#     ['pastas were full of flavor', 'FOOD', 0.7, 0.4]]},
#   '7': {'text': 'Though the Spider Roll may look like a challenge to eat, with soft shell crab hanging out of the roll, it is well worth the price you pay for them.',
#    'entities': [['Spider Roll', 'FOOD', 0.6, 0.3],
#     ['well worth the price', 'BEVERAGE', 0.5, 0.2]]},
#   '8': {'text': 'They came out over cooked and the cheese was almost non existent.',
#    'entities': [['came out over cooked', 'FOOD', 0.3, -0.4],
#     ['cheese was almost non existent', 'FOOD', 0.2, -0.5]]},
#   '9': {'text': 'The place was real empty but that was because this was the first Sunday they ever opened.',
#    'entities': [['place was real empty', 'AMBIENCE', 0.3, -0.4],
#     ['first Sunday they ever opened', 'SERVICE', 0.2, 0.1]]},
#   '10': {'text': 'We ordered some beef and noodle soup dishes from the Thai section of the menu but nothing we got was Thai.',
#    'entities': [['ordered some beef and noodle soup', 'FOOD', 0.5, 0.2],
#     ['Thai section of the menu', 'SERVICE', 0.3, -0.1]]}},
#  {'1': {'text': 'I have never had cheescake like this.',
#    'entities': [['cheesecake', 'FOOD', 0.8, 0.6]]},
#   '2': {'text': 'The cream cheeses are out of this world and I love that coffee!!',
#    'entities': [['cream cheeses', 'FOOD', 0.9, 0.7],
#     ['coffee', 'BEVERAGE', 0.8, 0.5]]},
#   '3': {'text': 'By far this is the only chinese desserts place I know in NY or anywhere close in the Northeastern America that serves desserts with frog jelly in a couple of varieties and pig feet ginger simmered in black vinegar.',
#    'entities': [['Chinese desserts', 'FOOD', 0.7, 0.4],
#     ['frog jelly', 'FOOD', 0.6, -0.2],
#     ['pig feet ginger', 'FOOD', 0.5, -0.3]]},
#   '4': {'text': "Won't or Can't is not in the service directory.",
#    'entities': [['service directory', 'SERVICE', 0.6, 0.1]]},
#   '5': {'text': 'You must have the crabmeat lasagna which is out of this world and the chocolate bread pudding for dessert.',
#    'entities': [['crabmeat lasagna', 'FOOD', 0.8, 0.6],
#     ['chocolate bread pudding', 'FOOD', 0.7, 0.4]]},
#   '6': {'text': "I would highly recommend Nina's to anyone who wants to have a romantic dinner in a heart warming surrounding filled with candles and family pictures.",
#    'entities': [['romantic dinner', 'SERVICE', 0.7, 0.4],
#     ['candles', 'AMBIENCE', 0.6, 0.3]]},
#   '7': {'text': 'Made my dining experience uncomfortable.',
#    'entities': [['dining experience', 'SERVICE', 0.5, -0.5]]},
#   '8': {'text': "This wasn't the expected menu comprised only of pad thai and tom yum soup, but I thought that was what made the place so special.",
#    'entities': [['menu', 'FOOD', 0.6, 0.2]]},
#   '9': {'text': 'Maybe I say so because it looked promising for people who like artery-clogging jewish deli food, but turns out to be poorly run and awful.',
#    'entities': [['Jewish deli food', 'FOOD', 0.5, -0.4],
#     ['poorly run', 'SERVICE', 0.3, -0.6]]},
#   '10': {'text': 'We had the most wonderful waitress.',
#    'entities': [['wonderful waitress', 'SERVICE', 0.9, 0.7]]}},
#  {'1': {'text': 'The food however, is what one might expect.',
#    'entities': [['food', 'FOOD', 0.7, 0.3]]},
#   '2': {'text': 'We had a great tiem watching the shows and characters and ar food was just what we were looking for.',
#    'entities': [['ar food', 'FOOD', 0.6, 0.4]]},
#   '3': {'text': "It's not mind-blowing, but to me, thai food never is and never will be.",
#    'entities': [['thai food', 'FOOD', 0.5, -0.2]]},
#   '4': {'text': 'The Pastrami sandwich was like buttah and with pickles and an icy cold beer to wash it down, it was a pleasurable experience.',
#    'entities': [['Pastrami sandwich', 'FOOD', 0.8, 0.6],
#     ['beer', 'BEVERAGE', 0.7, 0.4]]},
#   '5': {'text': 'We left after one drink.',
#    'entities': [['one drink', 'BEVERAGE', 0.3, -0.2]]},
#   '6': {'text': 'We ordered the special, grilled branzino, that was so infused with bone, it was difficult to eat.',
#    'entities': [['grilled branzino', 'FOOD', 0.4, -0.5]]},
#   '7': {'text': 'We visited Bread Bar during January restaurant week and were so pleased with the menu selections and service.',
#    'entities': []},
#   '8': {'text': 'Food was okay, nothing great.',
#    'entities': [['food', 'FOOD', 0.5, -0.2]]},
#   '9': {'text': 'After all that, they complained to me about the small tip.',
#    'entities': []},
#   '10': {'text': 'The food was absolutely amazing!!',
#    'entities': [['food', 'FOOD', 0.9, 0.7]]}},
#  {'1': {'text': 'brick oven gallery is My pick for best pizza restaurant anywhere.',
#    'entities': [['best pizza restaurant', 'FOOD', 0.8, 0.7]]},
#   '2': {'text': 'I complete the total bagel experience by having it lightly toasted.',
#    'entities': [['total bagel experience', 'FOOD', 0.6, 0.4],
#     ['lightly toasted', 'FOOD', 0.5, 0.3]]},
#   '3': {'text': "It's great to go for a quick lunch either alone or with a friend.",
#    'entities': [['quick lunch', 'SERVICE', 0.7, 0.4],
#     ['alone or with a friend', 'SERVICE', 0.6, 0.3]]},
#   '4': {'text': "The dim sum is ok but doesn't taste that fresh, and the little dishes don't look steamy hot as they should (also note lack of Chinese here).",
#    'entities': [['dim sum', 'FOOD', 0.5, -0.3],
#     ["doesn't taste that fresh", 'FOOD', 0.6, -0.4],
#     ["little dishes don't look steamy hot", 'SERVICE', 0.7, -0.5]]},
#   '5': {'text': 'Obv caviar is top of the line but the rest of the menu is so diverse it gives you a chance to taste so manydifferent varietys.',
#    'entities': [['caviar', 'FOOD', 0.8, 0.6],
#     ['rest of the menu', 'FOOD', 0.7, 0.4]]},
#   '6': {'text': 'To begin, we were told there was a 30 minute wait and started to leave, when the hostess offered to call us on our cell phone when the table was ready.',
#    'entities': [['30 minute wait', 'SERVICE', 0.5, -0.4],
#     ['hostess offered to call us', 'SERVICE', 0.6, 0.3]]},
#   '7': {'text': 'We had reservations at 9pm, but was not seated until 10:15pm.',
#    'entities': [['reservations', 'SERVICE', 0.5, -0.4],
#     ['not seated until 10:15pm', 'SERVICE', 0.6, -0.3]]},
#   '8': {'text': 'My boyfriend and I recently had an early dinner at Artisanal and was satisfied with our experience.',
#    'entities': [['early dinner', 'SERVICE', 0.7, 0.4],
#     ['satisfied with our experience', 'SERVICE', 0.8, 0.6]]},
#   '9': {'text': 'The service is descent even when this small place is packed.',
#    'entities': [['service is descent', 'SERVICE', 0.7, 0.4],
#     ['small place is packed', 'AMBIENCE', 0.6, -0.3]]},
#   '10': {'text': 'I have never better enjoyed humble root vegetables or a mushroom consomme - and this chef accomplishes without fats.',
#    'entities': [['humble root vegetables', 'FOOD', 0.8, 0.6],
#     ['mushroom consomme', 'FOOD', 0.7, 0.5]]}},
#  {'1': {'text': 'I cannot imagine better Indian food in all of the city.',
#    'entities': [['better Indian food', 'FOOD', 0.9, 0.8]]},
#   '2': {'text': 'NO more reservations, expensive tips and annoying stuff.',
#    'entities': [['expensive tips', 'SERVICE', 0.5, -0.7],
#     ['annoying stuff', 'AMBIENCE', 0.4, -0.6]]},
#   '3': {'text': 'This little place definitely exceeded my expectations and you sure get a lot of food for your money.',
#    'entities': [['exceeded my expectations', 'SERVICE', 0.8, 0.5],
#     ['get a lot of food for your money', 'FOOD', 0.7, 0.4]]},
#   '4': {'text': 'Get your food to go, find a bench, and kick back with a plate of dumplings.',
#    'entities': [['food to go', 'SERVICE', 0.6, 0.3],
#     ['dumplings', 'FOOD', 0.8, 0.7]]},
#   '5': {'text': 'Well, their deliveries take for ever and the food is usually cold.',
#    'entities': [['deliveries take for ever', 'SERVICE', 0.4, -0.6],
#     ['food is usually cold', 'FOOD', 0.3, -0.5]]},
#   '6': {'text': 'The food is so cheap and the waiters are nice.',
#    'entities': [['food is so cheap', 'FOOD', 0.8, 0.7],
#     ['waiters are nice', 'SERVICE', 0.9, 0.5]]},
#   '7': {'text': 'The entire dining experience was wonderful!',
#    'entities': [['entire dining experience was wonderful',
#      'AMBIENCE',
#      0.9,
#      0.8]]},
#   '8': {'text': "We got a little tipsy from the sake but isn't that what Saturday nights with the girlfriends are all about?",
#    'entities': [['got a little tipsy from the sake', 'BEVERAGE', 0.7, 0.4],
#     ['Saturday nights with the girlfriends', 'AMBIENCE', 0.6, 0.3]]},
#   '9': {'text': "The Pad thai, lad nar and various other dishes all look good on paper but, I've had better Thai food in less aesthetically pleasing places.",
#    'entities': [['Pad thai', 'FOOD', 0.8, 0.7],
#     ['had better Thai food', 'FOOD', 0.6, -0.4]]},
#   '10': {'text': 'The fish is fresh but the variety of fish is nothing out of ordinary.',
#    'entities': [['fish is fresh', 'FOOD', 0.8, 0.7],
#     ['variety of fish is nothing out of ordinary', 'FOOD', 0.4, -0.2]]}},
#  {'1': {'text': 'stick with the chicken, beef, and lamb dishes.',
#    'entities': [['chicken', 'FOOD', 0.7, 0.4],
#     ['beef', 'FOOD', 0.6, 0.3],
#     ['lamb', 'FOOD', 0.5, 0.2]]},
#   '2': {'text': "Tried the pad see ew on the recommendation of the last reviewer since it's one of my favorite dishes.",
#    'entities': [['pad see ew', 'FOOD', 0.6, 0.4],
#     ['recommendation of the last reviewer', 'SERVICE', 0.5, 0.3]]},
#   '3': {'text': 'When you want a piece of beef, head on over.',
#    'entities': [['piece of beef', 'FOOD', 0.7, 0.4]]},
#   '4': {'text': 'Try green curry with vegetables.',
#    'entities': [['green curry', 'FOOD', 0.6, 0.3],
#     ['vegetables', 'FOOD', 0.5, 0.2]]},
#   '5': {'text': 'A++   The service was good to excellent along with the attitude.',
#    'entities': [['service was good to excellent', 'SERVICE', 0.7, 0.4],
#     ['attitude', 'SERVICE', 0.6, 0.3]]},
#   '6': {'text': "Don't expect to sit down inside though, there are only a few tables and they are always full.",
#    'entities': [['sit down inside', 'AMBIENCE', 0.4, -0.4],
#     ['few tables and they are always full', 'AMBIENCE', 0.3, -0.3]]},
#   '7': {'text': "The wine selection (by the glass and bottle) is wonderful and I always recommend that friends make a reservation if they're going to be in town.",
#    'entities': [['wine selection', 'BEVERAGE', 0.6, 0.4],
#     ['make a reservation', 'SERVICE', 0.5, 0.3]]},
#   '8': {'text': 'Such nice people working here - but I have to review the food.',
#    'entities': [['nice people working here', 'SERVICE', 0.7, 0.4]]},
#   '9': {'text': 'This is one of the best comfort food places in the city.',
#    'entities': [['comfort food places', 'FOOD', 0.6, 0.3]]},
#   '10': {'text': "Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!",
#    'entities': [['sake list', 'BEVERAGE', 0.5, 0.2],
#     ['Purple Haze', 'BEVERAGE', 0.4, -0.4]]}},
#  {'1': {'text': 'I loved everythig about it-especially the shows and actors.',
#    'entities': [['loved everythig', 'OVERALL', 0.8, 0.7],
#     ['shows and actors', 'ENTERTAINMENT', 0.9, 0.6]]},
#   '2': {'text': 'Appetizers are somewhere around $7 each and the main dishes are between $11 and $16.',
#    'entities': [['$7 each', 'PRICE', 0.5, -0.1],
#     ['$11 and $16', 'PRICE', 0.6, -0.2]]},
#   '3': {'text': 'Le Pere Pinard has a $15 pre-theater menu that is outstanding.',
#    'entities': [['$15 pre-theater menu', 'FOOD', 0.8, 0.5],
#     ['outstanding', 'FOOD', 0.9, 0.6]]},
#   '4': {'text': 'Each bite of food at Kai was indeed delicious, fresh, and elegant.',
#    'entities': [['each bite of food', 'FOOD', 0.8, 0.5],
#     ['delicious, fresh, and elegant', 'FOOD', 0.9, 0.6]]},
#   '5': {'text': 'The grilled cheese at home afterwards was better.!!',
#    'entities': [['grilled cheese', 'FOOD', 0.7, -0.3],
#     ['better', 'FOOD', 0.8, 0.4]]},
#   '6': {'text': 'A narrow corridor leads to a tiny space where there are three tiny white tiled counters, a great deal of mess (stacks of bottles, cans) and a small counter holding 12-14 entrees.',
#    'entities': [['narrow corridor', 'AMBIENCE', 0.4, -0.5],
#     ['tiny space', 'AMBIENCE', 0.3, -0.6]]},
#   '7': {'text': 'We were very surprised by how good the food was on our first visit here on a Sunday night.',
#    'entities': [['very surprised', 'OVERALL', 0.8, 0.5],
#     ['how good the food', 'FOOD', 0.9, 0.6]]},
#   '8': {'text': 'Odd for Ave B, not just odd, The place attracts an eclectic crowd to say the least.',
#    'entities': [['odd', 'AMBIENCE', 0.4, -0.5],
#     ['eclectic crowd', 'CROWD', 0.6, 0.3]]},
#   '9': {'text': "But don't ever order bacon late at nite (either platter or in sandwiches, for that matter don't from any take out place) as it is from the morning frying turns out hard almost like bacos, hurt my molars.",
#    'entities': [["don't ever order bacon", 'FOOD', 0.5, -0.4],
#     ['late at nite', 'TIME', 0.6, -0.3]]},
#   '10': {'text': 'We have been to this place many times, and always have great food, wine, and service.',
#    'entities': [['great food', 'FOOD', 0.9, 0.6],
#     ['wine', 'BEVERAGE', 0.8, 0.5],
#     ['service', 'SERVICE', 0.7, 0.4]]}},
#  {'1': {'text': 'The place is a little tight and on a cold day, the seating by the entranceway can be pretty drafty.',
#    'entities': [['place is a little tight', 'AMBIENCE', 0.6, -0.4],
#     ['seating by the entranceway can be pretty drafty',
#      'AMBIENCE',
#      0.5,
#      -0.5]]},
#   '2': {'text': 'The website and rating makes this place look wonderful but in reality it was very disappointing.',
#    'entities': [['website and rating makes this place look wonderful',
#      'OVERALL',
#      0.4,
#      -0.6],
#     ['in reality it was very disappointing', 'OVERALL', 0.3, -0.7]]},
#   '3': {'text': 'but the service was a bit slow.',
#    'entities': [['service was a bit slow', 'SERVICE', 0.5, -0.4]]},
#   '4': {'text': 'The entertainment was great they have shows that go on through out the dinner.',
#    'entities': [['entertainment was great', 'ENTERTAINMENT', 0.7, 0.3],
#     ['shows that go on through out the dinner', 'ENTERTAINMENT', 0.6, 0.2]]},
#   '5': {'text': 'The lobster sandwich is good and the spaghetti with Scallops and Shrimp is great.',
#    'entities': [['lobster sandwich is good', 'FOOD', 0.7, 0.3],
#     ['spaghetti with Scallops and Shrimp is great', 'FOOD', 0.8, 0.4]]},
#   '6': {'text': 'The Prix Fixe menu is worth every penny and you get more than enough (both in quantity AND quality).',
#    'entities': [['Prix Fixe menu is worth every penny', 'FOOD', 0.8, 0.4],
#     ['you get more than enough', 'FOOD', 0.7, 0.3]]},
#   '7': {'text': 'The food is prepared quickly and efficiently.',
#    'entities': [['food is prepared quickly and efficiently',
#      'SERVICE',
#      0.6,
#      0.4]]},
#   '8': {'text': 'He was terribly thirsty after the meal too.',
#    'entities': [['was terribly thirsty after the meal',
#      'SERVICE',
#      0.5,
#      -0.3]]},
#   '9': {'text': "Thalia is a beautiful restaurant with beautiful people serving you, but the food doesn't quite match up.",
#    'entities': [['is a beautiful restaurant with beautiful people',
#      'AMBIENCE',
#      0.8,
#      0.4],
#     ["food doesn't quite match up", 'FOOD', 0.5, -0.3]]},
#   '10': {'text': 'like saying her bread comes from a special bakery when we have seen her buying it dowtown manhathan.',
#    'entities': [['bread comes from a special bakery', 'FOOD', 0.4, -0.2],
#     ['have seen her buying it dowtown manhathan', 'SERVICE', 0.3, -0.1]]}},
#  {'1': {'text': 'Wine list selection is good and wine-by-the-glass was generously filled to the top.',
#    'entities': [['wine list selection is good', 'BEVERAGE', 0.7, 0.4],
#     ['wine-by-the-glass was generously filled to the top',
#      'BEVERAGE',
#      0.6,
#      0.5]]},
#   '2': {'text': 'The bagels are also reasonably priced for NYC.',
#    'entities': [['bagels are also reasonably priced', 'FOOD', 0.7, 0.4]]},
#   '3': {'text': 'Has the chef and owner changed???', 'entities': []},
#   '4': {'text': 'Do not get the Go Go Hamburgers, no matter what the reviews say.',
#    'entities': [['Do not get the Go Go Hamburgers', 'FOOD', 0.6, -0.5]]},
#   '5': {'text': 'The service was typical short-order, dinner type.',
#    'entities': [['service was typical short-order', 'SERVICE', 0.4, 0.2],
#     ['dinner type', 'SERVICE', 0.3, 0.1]]},
#   '6': {'text': 'We both opted for a pasta dish and they were served timely and fresh.',
#    'entities': [['pasta dish', 'FOOD', 0.7, 0.4],
#     ['served timely and fresh', 'SERVICE', 0.6, 0.5]]},
#   '7': {'text': 'The food is nothing like its menu description.',
#    'entities': [['food is nothing like its menu description',
#      'FOOD',
#      0.4,
#      -0.4]]},
#   '8': {'text': 'I grew up on these bagels.', 'entities': []},
#   '9': {'text': 'I have been here a few times for dinner, once for brunch and twice for lunch.',
#    'entities': []},
#   '10': {'text': "You can't say its cheap because food is cheaper in Chinatown.",
#    'entities': [["can't say its cheap", 'VALUE', 0.5, -0.3],
#     ['food is cheaper in Chinatown', 'VALUE', 0.6, -0.4]]}},
#  {'1': {'text': 'The people in the restaurant were pretty obnoxious and loud.',
#    'entities': [['people in the restaurant were pretty obnoxious',
#      'SERVICE',
#      0.6,
#      -0.5],
#     ['loud', 'AMBIENCE', 0.7, -0.4]]},
#   '2': {'text': 'Disappointing food, lousy service.',
#    'entities': [['food was disappointing', 'FOOD', 0.6, -0.5],
#     ['lousy service', 'SERVICE', 0.7, -0.4]]},
#   '3': {'text': "Also, if you don't want to sit at a certain table, you don't have to!",
#    'entities': [["don't want to sit at a certain table",
#      'AMBIENCE',
#      0.5,
#      0.2]]},
#   '4': {'text': 'For the quality of food, a little too expensive.',
#    'entities': [['quality of food was good', 'FOOD', 0.7, 0.3],
#     ['a little too expensive', 'VALUE', 0.6, -0.2]]},
#   '5': {'text': 'The service, however, was a bright flower in a garden.',
#    'entities': [['service was good', 'SERVICE', 0.8, 0.4],
#     ['bright flower in a garden', 'AMBIENCE', 0.6, 0.3]]},
#   '6': {'text': 'It saves walking in and waiting for a table in the often noisy, crowded bar at dinnertime.',
#    'entities': [['saves walking in and waiting', 'SERVICE', 0.7, 0.4],
#     ['often noisy, crowded bar', 'AMBIENCE', 0.6, -0.5]]},
#   '7': {'text': 'First, the waiter who served us neglected to fill us in on the specials, which I would have chosen had I known about them.',
#    'entities': [['waiter neglected to fill us in', 'SERVICE', 0.6, -0.4],
#     ['specials were good', 'FOOD', 0.7, 0.3]]},
#   '8': {'text': "We've been to Grocery three times and not once has an item on the menu disappointed.",
#    'entities': [['been to Grocery three times', 'SERVICE', 0.6, 0.2],
#     ['item on the menu was good', 'FOOD', 0.8, 0.4]]},
#   '9': {'text': 'The sushi seemed pretty fresh and was adequately proportioned.',
#    'entities': [['sushi was fresh', 'FOOD', 0.7, 0.3],
#     ['was adequately proportioned', 'FOOD', 0.6, 0.2]]},
#   '10': {'text': "I've read some of the previews reviews - people are either not New Yorkers or have more appreciation for ambience then food.",
#    'entities': [['people are either not New Yorkers', 'SERVICE', 0.6, 0.2],
#     ['have more appreciation for ambience', 'AMBIENCE', 0.7, 0.3]]}},
#  {'1': {'text': 'Its location is good and the fact that Hutner College is near and their prices are very reasonable, makes students go back to Suan again and again.',
#    'entities': [['location is good', 'LOCATION', 0.7, 0.5],
#     ['Hutner College is near', 'LOCATION', 0.6, 0.4],
#     ['prices are very reasonable', 'PRICE', 0.8, 0.6]]},
#   '2': {'text': 'The service is fine and they allow you to enjoy the view.',
#    'entities': [['service is fine', 'SERVICE', 0.5, 0.3],
#     ['allow you to enjoy the view', 'VIEW', 0.7, 0.4]]},
#   '3': {'text': 'Orsay, is a very pleasnt throw back to traditional French food, and French service as well.',
#    'entities': [['is a very pleasnt throw back', 'AMBIENCE', 0.6, 0.4],
#     ['traditional French food', 'FOOD', 0.8, 0.5],
#     ['French service as well', 'SERVICE', 0.7, 0.3]]},
#   '4': {'text': "The food is consistently wonderful - I've been coming here for years, and the owner has always been accomodating and friendly.",
#    'entities': [['food is consistently wonderful', 'FOOD', 0.9, 0.7],
#     ['owner has always been accomodating and friendly', 'SERVICE', 0.8, 0.6]]},
#   '5': {'text': 'This place is the most Japanese it can ever get.',
#    'entities': [['is the most Japanese it can ever get',
#      'AMBIENCE',
#      0.7,
#      -0.3]]},
#   '6': {'text': 'The food was delicious (I had a halibut special, my husband had steak), and the service was top-notch.',
#    'entities': [['food was delicious', 'FOOD', 0.9, 0.7],
#     ['service was top-notch', 'SERVICE', 0.8, 0.6]]},
#   '7': {'text': 'I have never been disappointed but their true strength lays in their amazingly delicious and cheap lunch specials.',
#    'entities': [['never been disappointed', 'FOOD', 0.9, 0.5],
#     ['amazingly delicious and cheap lunch specials', 'FOOD', 0.8, 0.6]]},
#   '8': {'text': "Food doesn't appear to be cooked on premisis but there's a high turnover so its pretty fresh.",
#    'entities': [["doesn't appear to be cooked on premisis", 'FOOD', 0.4, -0.3],
#     ['high turnover so its pretty fresh', 'FOOD', 0.6, 0.2]]},
#   '9': {'text': "Get the soup and a nosh (pastrami sandwich) for $8 and you're golden.",
#    'entities': [['get the soup and a nosh', 'FOOD', 0.7, 0.4],
#     ["for $8 and you're golden", 'PRICE', 0.6, 0.3]]},
#   '10': {'text': 'The menu looked good, except for offering the Chilean Sea Bass, but the server does not offer up the specials that were written on the board outside.',
#    'entities': [['menu looked good', 'FOOD', 0.7, 0.4],
#     ['offering the Chilean Sea Bass', 'FOOD', 0.6, -0.2],
#     ['server does not offer up the specials', 'SERVICE', 0.5, -0.3]]}},
#  {'1': {'text': "i've been back to nha trang literally a hundred times for the beef cubes - they're that good.",
#    'entities': [['beef cubes', 'FOOD', 0.9, 0.8]]},
#   '2': {'text': "Service was devine, oysters where a sensual as they come, and the price can't be beat!!!",
#    'entities': [['service', 'SERVICE', 0.7, 0.6],
#     ['oysters', 'FOOD', 0.8, 0.5]]},
#   '3': {'text': 'I ordered tamarind duck and my wife ordered noodles with ground beef, and we were both delighted by the way the dishes evoked Thai flavors in unexpected ways.',
#    'entities': [['tamarind duck', 'FOOD', 0.8, 0.6],
#     ['noodles with ground beef', 'FOOD', 0.7, 0.4]]},
#   '4': {'text': 'Our waiter was fine, the place looks nice in that not-trying-too-hard way, but at those prices, a little more should be expected of your food.',
#    'entities': [['waiter', 'SERVICE', 0.5, 0.2], ['food', 'FOOD', 0.6, -0.3]]},
#   '5': {'text': "- the bread at the beginning is super tasty and makes you want more - the pizza is delicious and comes in personal sizes, however be warned that the Peter's Favourite pizza with prosciutto and baby arugula is actually a margarite pizza with cold prosciutto and baby arugula on top, like a salad.",
#    'entities': [['bread', 'FOOD', 0.8, 0.7], ['pizza', 'FOOD', 0.9, 0.6]]},
#   '6': {'text': 'instead ordered an ice cold beer which to me works with indian.',
#    'entities': [['beer', 'BEVERAGE', 0.7, 0.4]]},
#   '7': {'text': "Also, don't plan on asking for your favorite roll, if it's not on the menu, you can't have it.",
#    'entities': [['roll', 'FOOD', 0.5, -0.2]]},
#   '8': {'text': "Just don't take the seat between the bar and the back half of the restaurant, i saw a woman get nudged 40times sitting there.",
#    'entities': [['seat', 'AMBIENCE', 0.3, -0.5]]},
#   '9': {'text': 'It took them 15 minutes to put water in our glasses.',
#    'entities': [['service', 'SERVICE', 0.4, -0.6]]},
#   '10': {'text': 'Service is top notch.',
#    'entities': [['service', 'SERVICE', 0.9, 0.8]]}},
#  {'1': {'text': "Please if your thinking about it go, and stay the wait you won't be disappointed.",
#    'entities': [['thinking about it', 'GENERAL', 0.4, 0.2],
#     ["won't be disappointed", 'GENERAL', 0.6, 0.5]]},
#   '2': {'text': 'The service, wine selection, ambiance are all outstanding and deserve recognition.',
#    'entities': [['service', 'SERVICE', 0.7, 0.4],
#     ['wine selection', 'BEVERAGE', 0.6, 0.3],
#     ['ambiance', 'AMBIENCE', 0.5, 0.2]]},
#   '3': {'text': 'Service is not what one would expect from a joint in this price category.',
#    'entities': [['service', 'SERVICE', 0.4, -0.4],
#     ['price category', 'GENERAL', 0.5, 0.1]]},
#   '4': {'text': 'We have never had any problems with charging the meal or the tip, and the food was delivered quickly, but we live only a few minutes walk from them.',
#    'entities': [['charging the meal', 'SERVICE', 0.6, 0.3],
#     ['food was delivered quickly', 'FOOD', 0.7, 0.4]]},
#   '5': {'text': 'I like Cafe Noir dont get me wrong, it is jsut that the people who work there are evil and incompetent!!',
#    'entities': [['people who work there', 'SERVICE', 0.2, -0.6],
#     ['evil and incompetent', 'SERVICE', 0.1, -0.8]]},
#   '6': {'text': 'More important, the sushi rivals the best in Tokyo.',
#    'entities': [['sushi', 'FOOD', 0.7, 0.5], ['Tokyo', 'GENERAL', 0.4, 0.2]]},
#   '7': {'text': 'The bagels always warm, soft on the inside, crispy on the outside and enormous in size.',
#    'entities': [['bagels', 'FOOD', 0.6, 0.3], ['warm', 'GENERAL', 0.5, 0.2]]},
#   '8': {'text': "those rolls were big, but not good and sashimi wasn't fresh.",
#    'entities': [['rolls were big', 'FOOD', 0.4, -0.3],
#     ["sashimi wasn't fresh", 'FOOD', 0.2, -0.5]]},
#   '9': {'text': 'Other guests enjoyed pizza, santa fe chopped salad and fish and chips.',
#    'entities': [['pizza', 'FOOD', 0.6, 0.3],
#     ['santa fe chopped salad', 'FOOD', 0.5, 0.2],
#     ['fish and chips', 'FOOD', 0.7, 0.4]]},
#   '10': {'text': 'The staff was the friendliest that have seen in New York.',
#    'entities': [['staff', 'SERVICE', 0.8, 0.6],
#     ['friendliest', 'GENERAL', 0.7, 0.5]]}},
#  {'1': {'text': 'The desserts are more appealing then stuffy overpriced French restaurants.',
#    'entities': [['desserts are more appealing', 'FOOD', 0.7, 0.5],
#     ['stuffy overpriced French restaurants', 'AMBIENCE', 0.3, -0.6]]},
#   '2': {'text': 'The menu was impressive with selections ranging from a burger, to steak, to escargot.',
#    'entities': [['menu was impressive', 'FOOD', 0.8, 0.5],
#     ['burger, to steak, to escargot', 'FOOD', 0.6, 0.2]]},
#   '3': {'text': "If your visiting, you'll enjoy the ambiance and the fact that it's in Time Sq...",
#    'entities': [['enjoy the ambiance', 'AMBIENCE', 0.7, 0.4],
#     ["fact that it's in Time Sq", 'LOCATION', 0.6, 0.3]]},
#   '4': {'text': 'if this happens, just ask for real naan.',
#    'entities': [['ask for real naan', 'SERVICE', 0.5, 0.2]]},
#   '5': {'text': 'A very inviting restaurant, with friendly service.',
#    'entities': [['inviting restaurant', 'AMBIENCE', 0.8, 0.6],
#     ['friendly service', 'SERVICE', 0.7, 0.4]]},
#   '6': {'text': 'Moderate prices.',
#    'entities': [['moderate prices', 'PRICE', 0.5, 0.2]]},
#   '7': {'text': "Took my mom for Mother's Day, and the maitre d' was pretty rude.",
#    'entities': [["maitre d' was pretty rude", 'SERVICE', 0.3, -0.5]]},
#   '8': {'text': "If you're not familiar with the cuisine, you may encounter problems ordering here and be sure to bring plenty of cash with you as they don't accept credit cards.",
#    'entities': [['problems ordering', 'FOOD', 0.4, -0.3],
#     ['bring plenty of cash', 'PRICE', 0.6, -0.2]]},
#   '9': {'text': 'Three courses - choices include excellent mussels, puff pastry goat cheese and salad with a delicious dressing, and a hanger steak au poivre that is out of this world.',
#    'entities': [['excellent mussels', 'FOOD', 0.8, 0.6],
#     ['puff pastry goat cheese', 'FOOD', 0.7, 0.4],
#     ['hanger steak au poivre', 'FOOD', 0.9, 0.7]]},
#   '10': {'text': 'Saul is pretty good, but definitely not great.',
#    'entities': [['pretty good', 'FOOD', 0.6, 0.3],
#     ['definitely not great', 'FOOD', 0.4, -0.2]]}},
#  {'1': {'text': 'For the location, the prices are very reasonable.',
#    'entities': [['prices are very reasonable', 'VALUE', 0.8, 0.6]]},
#   '2': {'text': 'I found the food, service and value exceptional everytime I have been there.',
#    'entities': [['food is exceptional', 'FOOD', 0.9, 0.7],
#     ['service is exceptional', 'SERVICE', 0.9, 0.7],
#     ['value is exceptional', 'VALUE', 0.9, 0.7]]},
#   '3': {'text': "The place is small and intimate and you may feel a little crowded, but the service is excellent and it's great for friends out, a romantic date, or a special occassion.",
#    'entities': [['place is small and intimate', 'AMBIENCE', 0.6, 0.4],
#     ['service is excellent', 'SERVICE', 0.8, 0.5]]},
#   '4': {'text': 'The wait staff is very friendly, if not overly efficient.',
#    'entities': [['wait staff is very friendly', 'SERVICE', 0.7, 0.3],
#     ['wait staff is not overly efficient', 'SERVICE', 0.5, -0.2]]}},
#  {'1': {'text': 'The chicken and steak were seasoned and cooked to perfection, and the lamb sandwhich is great for heartier appetites.',
#    'entities': [['chicken and steak were seasoned and cooked to perfection',
#      'FOOD',
#      0.8,
#      0.7],
#     ['lamb sandwhich is great for heartier appetites', 'FOOD', 0.6, 0.4]]},
#   '2': {'text': 'Pizza was a little soggy.',
#    'entities': [['pizza was a little soggy', 'FOOD', 0.3, -0.5]]},
#   '3': {'text': 'There was a great deal for 6 Blue Point oysters and a beer or glass of wine for $8!',
#    'entities': [['great deal for 6 Blue Point oysters and a beer or glass of wine',
#      'BEVERAGE',
#      0.7,
#      0.5]]},
#   '4': {'text': 'IT IS WHAT MODERN CUISINE IS ALL ABOUT.',
#    'entities': [['modern cuisine is all about', 'FOOD', 0.6, 0.3]]},
#   '5': {'text': 'Not impressed with the food.',
#    'entities': [['not impressed with the food', 'FOOD', 0.2, -0.7]]},
#   '6': {'text': 'i would just ask for no oil next time.',
#    'entities': [['would just ask for no oil next time', 'SERVICE', 0.5, 0.3]]},
#   '7': {'text': 'I do not recommend lunch specials just because it tasts the same with other regular chinese restaurant.',
#    'entities': [['do not recommend lunch specials', 'FOOD', 0.2, -0.6],
#     ['tastes the same with other regular chinese restaurant',
#      'FOOD',
#      0.3,
#      -0.4]]},
#   '8': {'text': 'service is friendly, and never had a problem walking in and getting a table.',
#    'entities': [['service is friendly', 'SERVICE', 0.7, 0.5],
#     ['never had a problem walking in and getting a table',
#      'SERVICE',
#      0.6,
#      0.4]]},
#   '9': {'text': 'The service was attentive without being overbearing and each dish we tried was wonderful from the spring rolls to the cod with pineapple tempura.',
#    'entities': [['service was attentive without being overbearing',
#      'SERVICE',
#      0.8,
#      0.6],
#     ['each dish we tried was wonderful', 'FOOD', 0.7, 0.5]]},
#   '10': {'text': 'Even the pasta is delicious here (a rarity in New York pizza restaurants).',
#    'entities': [['pasta is delicious here', 'FOOD', 0.8, 0.6]]}},
#  {'1': {'text': 'Spreads and toppings are great - though a bit pricey.',
#    'entities': [['spreads and toppings are great', 'FOOD', 0.8, 0.4],
#     ['a bit pricey', 'PRICE', 0.5, -0.3]]},
#   '2': {'text': 'Pizza and garlic knots are great as well, I order from them quite often and the delivery is always super quick!',
#    'entities': [['pizza and garlic knots are great', 'FOOD', 0.8, 0.5],
#     ['order from them quite often', 'SERVICE', 0.6, 0.3],
#     ['delivery is always super quick', 'SERVICE', 0.7, 0.4]]},
#   '3': {'text': 'While they keep the capex to a minimum, they do put some cash into the bagels, because they among the best in the city.',
#    'entities': [['put some cash into the bagels', 'FOOD', 0.6, 0.4],
#     ['among the best in the city', 'FOOD', 0.7, 0.5]]},
#   '4': {'text': 'I have been there many times, and food is good and consistent.',
#    'entities': [['food is good and consistent', 'FOOD', 0.8, 0.6]]},
#   '5': {'text': 'Slightly above average wines start at $70+ with only one selection listed at $30+.',
#    'entities': [['wines start at $70+', 'BEVERAGE', 0.7, -0.4],
#     ['only one selection listed at $30+', 'BEVERAGE', 0.5, -0.3]]},
#   '6': {'text': 'We were disappointed with the pre-fixe menu of only 2 choices per course (other restaurants offer 3 choices) and ended up ordering a la carte.',
#    'entities': [['pre-fixe menu of only 2 choices', 'SERVICE', 0.4, -0.5],
#     ['ordering a la carte', 'SERVICE', 0.6, 0.3]]},
#   '7': {'text': 'Well, this place is so Ghetto its not even funny.',
#    'entities': [['place is so Ghetto', 'AMBIENCE', 0.2, -0.8]]},
#   '8': {'text': 'black white shakes came out good also.',
#    'entities': [['shakes came out good', 'FOOD', 0.7, 0.4]]},
#   '9': {'text': 'So much more than the usual bar food, go there to enjoy the menu while sampling one of their hand-crafted beers.',
#    'entities': [['more than the usual bar food', 'FOOD', 0.8, 0.5],
#     ['hand-crafted beers', 'BEVERAGE', 0.7, 0.4]]},
#   '10': {'text': 'If the weather is nice, try to snag an outside table.',
#    'entities': [['outside table', 'AMBIENCE', 0.6, 0.3]]}},
#  {'1': {'text': 'Pizza is terrific, as is homemade pasta.',
#    'entities': [['is terrific', 'FOOD', 0.7, 0.6],
#     ['homemade pasta', 'FOOD', 0.8, 0.5]]},
#   '2': {'text': "I've never had bad service and the fish is fresh and delicious.",
#    'entities': [['never had bad service', 'SERVICE', 0.9, 0.7],
#     ['fish is fresh and delicious', 'FOOD', 0.8, 0.6]]},
#   '3': {'text': 'Of course the reason its so packed is because the food is so delicious!',
#    'entities': [['reason its so packed', 'AMBIENCE', 0.5, -0.1],
#     ['food is so delicious', 'FOOD', 0.9, 0.8]]},
#   '4': {'text': "A restaurant that doesn't try to do anything except serve great food with great service in a pleasant atmosphere.",
#    'entities': [['great food', 'FOOD', 0.8, 0.6],
#     ['great service', 'SERVICE', 0.9, 0.7],
#     ['pleasant atmosphere', 'AMBIENCE', 0.7, 0.4]]},
# ...
#   '14': {'text': "My husband said the portions were very small, but if my main course was good to eat the portion would've been fine for me.",
#    'entities': [['portions were very small', 'FOOD', 0.5, -0.4],
#     ['good to eat', 'FOOD', 0.7, 0.3]]},
#   '15': {'text': 'The waitresses are nice--also you can just get counter service sit.',
#    'entities': [['waitresses are nice', 'SERVICE', 0.8, 0.4],
#     ['counter service sit', 'SERVICE', 0.6, 0.2]]},
#   '16': {'text': 'The design and atmosphere is just as good.',
#    'entities': [['design and atmosphere is just as good',
#      'AMBIENCE',
#      0.7,
#      0.3]]},
#   '17': {'text': 'The food was pretty good, but a little flavorless and the portions very small, including dessert.',
#    'entities': [['food was pretty good', 'FOOD', 0.6, 0.2],
#     ['a little flavorless', 'FOOD', 0.5, -0.3],
#     ['portions very small', 'FOOD', 0.5, -0.4]]},
#   '18': {'text': 'Scalina Fedeli reminded me why service is so integral to fine dining.',
#    'entities': [['service is so integral to fine dining',
#      'SERVICE',
#      0.8,
#      0.6]]},
#   '19': {'text': 'Again, the waitress was awesome.',
#    'entities': [['waitress was awesome', 'SERVICE', 0.9, 0.7]]},
#   '20': {'text': 'We visited Orsay during NY Restaurant Week and tried their $35 menu.',
#    'entities': []}},
#  {'1': {'text': 'Wait staff is blantently unappreciative of your business but its the best pie on the UWS!',
#    'entities': [['wait staff is blantently unappreciative',
#      'SERVICE',
#      0.6,
#      -0.5],
#     ['best pie on the UWS', 'FOOD', 0.8, 0.7]]},
#   '2': {'text': "if you're looking for perfect traditional sushi, go here - if you're looking for interesting combinations, try sushi of gari's (east side).",
#    'entities': [['perfect traditional sushi', 'FOOD', 0.7, 0.5],
#     ['interesting combinations', 'FOOD', 0.6, 0.3]]},
#   '3': {'text': 'and yes Dal Bukhara is so dam good and so are all the kababs.',
#    'entities': [['Dal Bukhara is so dam good', 'FOOD', 0.9, 0.8],
#     ['all the kababs', 'FOOD', 0.7, 0.6]]},
#   '4': {'text': 'I found the variety of the sashimi plate to be satisfying - fresh and yummy.',
#    'entities': [['variety of the sashimi plate', 'FOOD', 0.8, 0.7],
#     ['fresh and yummy', 'FOOD', 0.9, 0.6]]},
#   '5': {'text': 'The secret is the lunch menu which offers a complimentary appetizer with every entree ordered.',
#    'entities': [['lunch menu', 'MENU', 0.7, 0.4],
#     ['complimentary appetizer', 'SERVICE', 0.8, 0.5]]},
#   '6': {'text': "My suggestion is to eat family style because you'll want to try the other dishes.",
#    'entities': [['eat family style', 'SERVICE', 0.7, 0.4],
#     ['try the other dishes', 'FOOD', 0.8, 0.6]]},
#   '7': {'text': "It's constantly open, catering to the Pakistani cabbies lined up on Crosby St., so there's more turnover with the food than you'd expect (i.e., surprisingly fresh).",
#    'entities': [['constantly open', 'HOURS', 0.6, 0.3],
#     ['Pakistani cabbies', 'CATERING', 0.5, -0.2],
#     ['surprisingly fresh', 'FOOD', 0.8, 0.7]]},
#   '8': {'text': 'Kind of a small place but I guess if they are not too busy might be able to fit a group or kids.',
#    'entities': [['small place', 'AMBIENCE', 0.4, -0.3],
#     ['fit a group or kids', 'SERVICE', 0.6, 0.4]]},
#   '9': {'text': "I've dined at Alain Ducasse's restaurant in Monte Carlo for half the price for the same excellent dining experience.",
#    'entities': [["dined at Alain Ducasse's", 'SERVICE', 0.7, 0.5],
#     ['excellent dining experience', 'FOOD', 0.9, 0.8]]},
#   '10': {'text': 'Food is usually very good, though ocasionally I wondered about freshmess of raw vegatables in side orders.',
#    'entities': [['food is usually very good', 'FOOD', 0.8, 0.7],
#     ['freshness of raw vegetables', 'FOOD', 0.6, -0.3]]}},
#  {'1': {'text': 'First off, the waitress was completely unattentive the 2 times we saw her(odd in a restaurant with 6 tables) and got our order wrong.',
#    'entities': [['waitress was completely unattentive', 'SERVICE', 0.8, -0.7],
#     ['got our order wrong', 'FOOD', 0.5, -0.4]]},
#   '2': {'text': 'This is definitely an  excellent date spot because of the ambiance and on the weekends the  night scene is more than alive.',
#    'entities': [['ambiance', 'AMBIENCE', 0.9, 0.6],
#     ['night scene is more than alive', 'AMBIENCE', 0.7, 0.5]]},
#   '3': {'text': "Succulent steaks cooked precisely to your desired 'doneness' accompanied by salads and sides that don't look like leafy road kill.",
#    'entities': [['steaks cooked precisely', 'FOOD', 0.8, 0.5],
#     ['salads and sides', 'FOOD', 0.6, 0.2]]},
#   '4': {'text': 'I have been about 4 times and have always had a great meal.',
#    'entities': [['have always had a great meal', 'FOOD', 0.9, 0.7]]},
#   '5': {'text': 'It looked like shredded cheese partly done - still in strips.',
#    'entities': [['looked like shredded cheese', 'FOOD', 0.4, -0.3]]},
#   '6': {'text': 'I ordered a Lassi and asked 4 times for it but never got it.',
#    'entities': [['ordered a Lassi', 'BEVERAGE', 0.7, 0.5],
#     ['asked 4 times for it but never got it', 'SERVICE', 0.3, -0.6]]},
#   '7': {'text': 'Why do people rave about the ambience.',
#    'entities': [['rave about the ambience', 'AMBIENCE', 0.5, 0.2]]},
#   '8': {'text': 'Good spreads, great beverage selections and bagels really tasty.',
#    'entities': [['good spreads', 'FOOD', 0.7, 0.4],
#     ['great beverage selections', 'BEVERAGE', 0.9, 0.6],
#     ['bagels really tasty', 'FOOD', 0.8, 0.5]]},
#   '9': {'text': 'Unfortunately, the food is outstanding, but everything else about this restaurant is the pits.',
#    'entities': [['food is outstanding', 'FOOD', 0.9, 0.7],
#     ['everything else about this restaurant is the pits',
#      'SERVICE',
#      0.2,
#      -0.8]]},
#   '10': {'text': 'If you want Americanized Chinese food with your usual watery, generic white sauce, this is your place.',
#    'entities': [['Americanized Chinese food', 'FOOD', 0.6, 0.2],
#     ['watery, generic white sauce', 'FOOD', 0.4, -0.3]]}},
#  {'1': {'text': 'at taj, vegetarians can rejoice-all the dishes are manna from heaven.',
#    'entities': [['vegetarians can rejoice', 'FOOD', 0.8, 0.6],
#     ['all the dishes are manna from heaven', 'FOOD', 0.7, 0.5]]},
#   '2': {'text': "The one vegetarian entree (Abby's treasure) was actually quite a surprise - it was delicious and had wintermelon covering an assortment of fresh mushrooms and vegetables.",
#    'entities': [['vegetarian entree', 'FOOD', 0.6, 0.4],
#     ['wintermelon covering an assortment of fresh mushrooms and vegetables',
#      'FOOD',
#      0.7,
#      0.5]]},
#   '3': {'text': "Besides, when you have bad service, that's less money you have to tip.",
#    'entities': [['bad service', 'SERVICE', 0.6, -0.4],
#     ['less money you have to tip', 'SERVICE', 0.7, -0.5]]},
#   '4': {'text': 'Ive been here so many times the waiters know my name.',
#    'entities': [['waiters know my name', 'SERVICE', 0.8, 0.6]]},
#   '5': {'text': 'In summer-eat outside on a terrace (another great feature of Suan)!!!',
#    'entities': [['eat outside on a terrace', 'AMBIENCE', 0.7, 0.4],
#     ['great feature of Suan', 'AMBIENCE', 0.6, 0.3]]},
#   '6': {'text': "Don't eat here unless you're starving for thai food and you work next door.",
#    'entities': [['starving for thai food', 'FOOD', 0.8, 0.5],
#     ['work next door', 'SERVICE', 0.7, -0.2]]},
#   '7': {'text': 'Quality ingredients preparation all around, and a very fair price for NYC.',
#    'entities': [['quality ingredients', 'FOOD', 0.9, 0.6],
#     ['preparation all around', 'FOOD', 0.8, 0.5],
#     ['very fair price for NYC', 'SERVICE', 0.7, 0.4]]},
#   '8': {'text': 'The wait staff is friendly, and the food has gotten better and better!',
#    'entities': [['wait staff is friendly', 'SERVICE', 0.9, 0.6],
#     ['food has gotten better and better', 'FOOD', 0.8, 0.5]]},
#   '9': {'text': 'The food is amazing!!!!',
#    'entities': [['food is amazing', 'FOOD', 0.9, 0.7]]},
#   '10': {'text': 'The last two times I ordered from here my food was soo spicy that  I could barely eat it, and the spice took away from the flavor of the dish.',
#    'entities': [['food was soo spicy', 'FOOD', 0.6, -0.4],
#     ['spice took away from the flavor of the dish', 'FOOD', 0.7, -0.3]]}},
#  {'1': {'text': "It's like they took leftover chicken, poured oil and sprinkled pepper powder over it (the sauce was translucent and red).",
#    'entities': [['leftover chicken', 'FOOD', 0.6, -0.5],
#     ['oil and sprinkled pepper powder', 'FOOD', 0.7, -0.3]]},
#   '2': {'text': "Faan's got a great concept but a little rough on the delivery.",
#    'entities': [['got a great concept', 'SERVICE', 0.8, 0.4],
#     ['a little rough on the delivery', 'SERVICE', 0.5, -0.3]]},
#   '3': {'text': 'The pickles were great addition.',
#    'entities': [['pickles were great', 'FOOD', 0.9, 0.6]]},
#   '4': {'text': 'The ambiance is minimal the food is not phenomenal, but some dishes are quite good, such as the eggplant parmesan, veal in carozza chicken saltimbocca.',
#    'entities': [['ambiance is minimal', 'AMBIENCE', 0.3, -0.4],
#     ['food is not phenomenal', 'FOOD', 0.5, -0.2],
#     ['eggplant parmesan', 'FOOD', 0.8, 0.4],
#     ['veal in carozza chicken saltimbocca', 'FOOD', 0.9, 0.6]]},
#   '5': {'text': 'Prices too high for this cramped and unappealing resturant.',
#    'entities': [['prices too high', 'PRICE', 0.8, -0.7],
#     ['cramped and unappealing', 'AMBIENCE', 0.2, -0.6]]},
#   '6': {'text': 'I love when restaurants think using fancy expensive ingrediants makes the food fine cuisine, even with no idea how to use them.',
#    'entities': [['using fancy expensive ingrediants', 'FOOD', 0.7, -0.5],
#     ['makes the food fine cuisine', 'FOOD', 0.6, 0.2]]},
#   '7': {'text': 'The menu consisted of standard brassiere food, better then places like Balthazar etc.',
#    'entities': [['menu consisted of standard brassiere food',
#      'FOOD',
#      0.8,
#      0.4],
#     ['better then places like Balthazar', 'SERVICE', 0.9, 0.6]]},
#   '8': {'text': 'The menu is nothing like the one on the website.',
#    'entities': [['menu is nothing like the one on the website',
#      'SERVICE',
#      0.5,
#      -0.4]]},
#   '9': {'text': 'They were such a rip-off ($8.95 for four small meat patties in steamed buns) and not worth trying.',
#    'entities': [['were such a rip-off', 'PRICE', 0.2, -0.7],
#     ['four small meat patties in steamed buns', 'FOOD', 0.3, -0.4]]},
#   '10': {'text': 'As we were sitting eating the subpar food the manager proceeded to berate a couple of his employees for putting out the wrong containers for condiments and explained to them how expensive these containers were.',
#    'entities': [['sitting eating the subpar food', 'FOOD', 0.2, -0.5],
#     ['manager proceeded to berate', 'SERVICE', 0.1, -0.6]]}},
#  {'1': {'text': 'Our waiter and all of the people helping him were attentive and genuine.',
#    'entities': [['waiter and all of the people helping him',
#      'SERVICE',
#      0.8,
#      0.6],
#     ['were attentive and genuine', 'SERVICE', 0.7, 0.5]]},
#   '2': {'text': 'The sushi has been from average to below average, the wait service has always been sub-par the atmosphere goes from nice to really irritating (if you sit in the area beyond the kitchen, the acousitcs are horrid, everything echoes is extremely loud).',
#    'entities': [['sushi has been from average to below average',
#      'FOOD',
#      0.4,
#      -0.5],
#     ['wait service has always been sub-par', 'SERVICE', 0.3, -0.6],
#     ['atmosphere goes from nice to really irritating',
#      'AMBIENCE',
#      0.2,
#      -0.7]]},
#   '3': {'text': 'The chicken pot pie is excpetiona, the cheeseburger huge and delictable, and the service professional wan warm.',
#    'entities': [['chicken pot pie is excpetiona', 'FOOD', 0.9, 0.8],
#     ['cheeseburger huge and delictable', 'FOOD', 0.8, 0.7],
#     ['service professional wan warm', 'SERVICE', 0.6, 0.4]]},
#   '4': {'text': 'But, they were too big for the bun.',
#    'entities': [['they were too big for the bun', 'FOOD', 0.5, -0.3]]},
#   '5': {'text': 'The food is great and reasonably priced.',
#    'entities': [['food is great', 'FOOD', 0.8, 0.6],
#     ['reasonably priced', 'VALUE', 0.7, 0.4]]},
#   '6': {'text': "It was nice and fresh, but I can't give it high scores on being authentic thai.",
#    'entities': [['was nice and fresh', 'FOOD', 0.8, 0.5],
#     ["can't give it high scores on being authentic thai",
#      'CULTURE',
#      0.4,
#      -0.3]]},
#   '7': {'text': 'My co-workers had to wait almost an hour for delivery, only to discover that what they got was not what they ordered.',
#    'entities': [['co-workers had to wait almost an hour',
#      'SERVICE',
#      0.2,
#      -0.6],
#     ['what they got was not what they ordered', 'FOOD', 0.1, -0.5]]},
#   '8': {'text': 'Same owner as the guy who owns Typhoon, which is just down the street on St. Marks and 1st Ave.',
#    'entities': [['same owner as the guy who owns Typhoon',
#      'CULTURE',
#      0.3,
#      0.2],
#     ['which is just down the street on St. Marks and 1st Ave',
#      'LOCATION',
#      0.4,
#      0.3]]},
#   '9': {'text': 'Service is not exactly five star, but thats not really a big deal.',
#    'entities': [['service is not exactly five star', 'SERVICE', 0.2, -0.5],
#     ['thats not really a big deal', 'VALUE', 0.3, 0.1]]},
#   '10': {'text': 'The restaurant is dark and not very attractive and then you have spot lights shining on you putting you in the worst light possible, reaching for sunglasses.',
#    'entities': [['restaurant is dark and not very attractive',
#      'AMBIENCE',
#      0.1,
#      -0.6],
#     ['spot lights shining on you', 'AMBIENCE', 0.2, -0.5]]}},
#  {'1': {'text': "It's like they took leftover chicken, poured oil and sprinkled pepper powder over it (the sauce was translucent and red).",
#    'entities': [['leftover chicken', 'FOOD', 0.6, -0.5],
#     ['oil and sprinkled pepper powder', 'FOOD', 0.7, -0.3]]},
#   '2': {'text': "Faan's got a great concept but a little rough on the delivery.",
#    'entities': [['got a great concept', 'SERVICE', 0.8, 0.4],
#     ['a little rough on the delivery', 'SERVICE', 0.5, -0.3]]},
#   '3': {'text': 'The pickles were great addition.',
#    'entities': [['pickles were great', 'FOOD', 0.9, 0.6]]},
#   '4': {'text': 'The ambiance is minimal the food is not phenomenal, but some dishes are quite good, such as the eggplant parmesan, veal in carozza chicken saltimbocca.',
#    'entities': [['ambiance is minimal', 'AMBIENCE', 0.3, -0.4],
#     ['food is not phenomenal', 'FOOD', 0.5, -0.2],
#     ['eggplant parmesan', 'FOOD', 0.8, 0.4],
#     ['veal in carozza chicken saltimbocca', 'FOOD', 0.9, 0.6]]},
#   '5': {'text': 'Prices too high for this cramped and unappealing resturant.',
#    'entities': [['prices too high', 'PRICE', 0.8, -0.7],
#     ['cramped and unappealing', 'AMBIENCE', 0.2, -0.6]]},
#   '6': {'text': 'I love when restaurants think using fancy expensive ingrediants makes the food fine cuisine, even with no idea how to use them.',
#    'entities': [['using fancy expensive ingrediants', 'FOOD', 0.7, -0.5],
#     ['makes the food fine cuisine', 'FOOD', 0.6, 0.2]]},
#   '7': {'text': 'The menu consisted of standard brassiere food, better then places like Balthazar etc.',
#    'entities': [['menu consisted of standard brassiere food',
#      'FOOD',
#      0.8,
#      0.4],
#     ['better then places like Balthazar', 'SERVICE', 0.9, 0.6]]},
#   '8': {'text': 'The menu is nothing like the one on the website.',
#    'entities': [['menu is nothing like the one on the website',
#      'SERVICE',
#      0.5,
#      -0.4]]},
#   '9': {'text': 'They were such a rip-off ($8.95 for four small meat patties in steamed buns) and not worth trying.',
#    'entities': [['were such a rip-off', 'PRICE', 0.2, -0.7],
#     ['four small meat patties in steamed buns', 'FOOD', 0.3, -0.4]]},
#   '10': {'text': 'As we were sitting eating the subpar food the manager proceeded to berate a couple of his employees for putting out the wrong containers for condiments and explained to them how expensive these containers were.',
#    'entities': [['sitting eating the subpar food', 'FOOD', 0.2, -0.5],
#     ['manager proceeded to berate', 'SERVICE', 0.1, -0.6]]}}]

# %% [markdown]
# # Persist sampled

# %%
PERSIST_FP = '../data/output/llm_extract_output_20240706095040_100_sample.json'

fp = PERSIST_FP
with open(fp, 'w') as f:
    json.dump(sampled_extracted, f)

# %% [markdown]
# # Convert data to Label Studio format

# %%
import json
import uuid

# Sample source format data
source_data = [
    {
        "11": {
            "text": "The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.",
            "entities": [
                [
                    "looks out over beautiful green lawns",
                    "VIEW",
                    0.7,
                    0.5
                ],
                [
                    "Hudson River and the Statue of Liberty",
                    "VIEW",
                    0.8,
                    0.6
                ]
            ]
        }
    }
]

def find_entity_positions(text, entity_text):
    start = text.find(entity_text)
    if start == -1:
        return None, None
    end = start + len(entity_text)
    return start, end

def convert_format(source_data):
    target_data = []
    
    for item in source_data:
        for key, value in item.items():
            text = value["text"]
            entities = value["entities"]
            predictions = []
            scores = []

            for entity in entities:
                entity_text, entity_label, entity_score1, entity_score2 = entity
                start, end = find_entity_positions(text, entity_text)
                
                if start is not None and end is not None:
                    prediction = {
                        "id": str(uuid.uuid4()),
                        "from_name": "label",
                        "to_name": "text",
                        "type": "labels",
                        "value": {
                            "start": start,
                            "end": end,
                            "score": entity_score1,
                            "text": entity_text,
                            "labels": [
                                entity_label
                            ]
                        }
                    }
                    predictions.append(prediction)
                    scores.append(entity_score1)

            avg_score = np.mean(scores) if scores else 0.0
            target_item = {
                "data": {
                    "text": text
                },
                "predictions": [
                    {
                        "model_version": "one",
                        "score": avg_score,
                        "result": predictions
                    }
                ]
            }
            target_data.append(target_item)
    
    return target_data

# Convert the source data
converted_data = convert_format(source_data)

# Print the converted data in target format
print(json.dumps(converted_data, indent=2))
# Out:
# [
#   {
#     "data": {
#       "text": "The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty."
#     },
#     "predictions": [
#       {
#         "model_version": "one",
#         "score": 0.75,
#         "result": [
#           {
#             "id": "6c6883c6-4fa5-406f-8545-f3bf67872aab",
#             "from_name": "label",
#             "to_name": "text",
#             "type": "labels",
#             "value": {
#               "start": 15,
#               "end": 51,
#               "score": 0.7,
#               "text": "looks out over beautiful green lawns",
#               "labels": [
#                 "VIEW"
#               ]
#             }
#           },
#           {
#             "id": "94c4938c-2af4-4a08-9391-da4fcfaf79bd",
#             "from_name": "label",
#             "to_name": "text",
#             "type": "labels",
#             "value": {
#               "start": 59,
#               "end": 97,
#               "score": 0.8,
#               "text": "Hudson River and the Statue of Liberty",
#               "labels": [
#                 "VIEW"
#               ]
#             }
#           }
#         ]
#       }
#     ]
#   }
# ]

# %%
source_data = sampled_extracted

# Convert the source data
converted_data = convert_format(source_data)

# %%
len(converted_data)
# Out:
# 994

# %% [markdown]
# # Persist sampled Label Studio data

# %%
PERSIST_FP = '../data/output/llm_extract_output_20240706095040_100_sample_label_studio.json'

fp = PERSIST_FP
with open(fp, 'w') as f:
    json.dump(converted_data, f, indent=2)
